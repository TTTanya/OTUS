# %%
import numpy as np
import pandas as pd
import featuretools as ft
from featuretools import selection
from sklearn.preprocessing import RobustScaler, StandardScaler, MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.calibration import CalibratedClassifierCV
from sklearn.model_selection import StratifiedKFold

from lightgbm import LGBMClassifier

from sklearn.metrics import roc_auc_score, make_scorer
from sklearn.pipeline import make_union, make_pipeline
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

from category_encoders import OrdinalEncoder, OneHotEncoder
from category_encoders import BackwardDifferenceEncoder, HelmertEncoder, BinaryEncoder
from category_encoders import CountEncoder
from category_encoders import LeaveOneOutEncoder, TargetEncoder, JamesSteinEncoder, MEstimateEncoder, WOEEncoder, CatBoostEncoder
from category_encoders.wrapper import NestedCVWrapper

from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import SelectKBest, SelectPercentile
from sklearn.feature_selection import chi2, mutual_info_classif

from mlxtend.feature_selection import SequentialFeatureSelector

from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression 
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier

import h2o
from h2o.sklearn import H2OAutoMLClassifier
from h2o.sklearn import H2OGradientBoostingClassifier

from tpot import TPOTClassifier
from gama import GamaClassifier

from sklearn.feature_selection import RFECV

from nni.algorithms.feature_engineering.gradient_selector import FeatureGradientSelector
from nni.algorithms.feature_engineering.gbdt_selector import GBDTSelector

from imblearn.over_sampling import RandomOverSampler, SMOTE

import time
pd.set_option('display.max_rows', None)

# %%
train_feat = pd.read_csv('training_set_features.csv')
train_lab = pd.read_csv('training_set_labels.csv')
test_feat = pd.read_csv('test_set_features.csv')

# %%
train_feat.describe()
# Out:
#        respondent_id  h1n1_concern  h1n1_knowledge  behavioral_antiviral_meds  \
# count   26707.000000  26615.000000    26591.000000               26636.000000
# mean    13353.000000      1.618486        1.262532                   0.048844
# std      7709.791156      0.910311        0.618149                   0.215545
# min         0.000000      0.000000        0.000000                   0.000000
# 25%      6676.500000      1.000000        1.000000                   0.000000
# 50%     13353.000000      2.000000        1.000000                   0.000000
# 75%     20029.500000      2.000000        2.000000                   0.000000
# max     26706.000000      3.000000        2.000000                   1.000000
#
#        behavioral_avoidance  behavioral_face_mask  behavioral_wash_hands  \
# count          26499.000000          26688.000000           26665.000000
# mean               0.725612              0.068982               0.825614
# std                0.446214              0.253429               0.379448
# min                0.000000              0.000000               0.000000
# 25%                0.000000              0.000000               1.000000
# 50%                1.000000              0.000000               1.000000
# 75%                1.000000              0.000000               1.000000
# max                1.000000              1.000000               1.000000
#
#        behavioral_large_gatherings  behavioral_outside_home  \
# count                  26620.00000             26625.000000
# mean                       0.35864                 0.337315
# std                        0.47961                 0.472802
# min                        0.00000                 0.000000
# 25%                        0.00000                 0.000000
# 50%                        0.00000                 0.000000
# 75%                        1.00000                 1.000000
# max                        1.00000                 1.000000
#
#        behavioral_touch_face  ...  health_worker  health_insurance  \
# count           26579.000000  ...   25903.000000       14433.00000
# mean                0.677264  ...       0.111918           0.87972
# std                 0.467531  ...       0.315271           0.32530
# min                 0.000000  ...       0.000000           0.00000
# 25%                 0.000000  ...       0.000000           1.00000
# 50%                 1.000000  ...       0.000000           1.00000
# 75%                 1.000000  ...       0.000000           1.00000
# max                 1.000000  ...       1.000000           1.00000
#
#        opinion_h1n1_vacc_effective  opinion_h1n1_risk  \
# count                 26316.000000       26319.000000
# mean                      3.850623           2.342566
# std                       1.007436           1.285539
# min                       1.000000           1.000000
# 25%                       3.000000           1.000000
# 50%                       4.000000           2.000000
# 75%                       5.000000           4.000000
# max                       5.000000           5.000000
#
#        opinion_h1n1_sick_from_vacc  opinion_seas_vacc_effective  \
# count                 26312.000000                 26245.000000
# mean                      2.357670                     4.025986
# std                       1.362766                     1.086565
# min                       1.000000                     1.000000
# 25%                       1.000000                     4.000000
# 50%                       2.000000                     4.000000
# 75%                       4.000000                     5.000000
# max                       5.000000                     5.000000
#
#        opinion_seas_risk  opinion_seas_sick_from_vacc  household_adults  \
# count       26193.000000                 26170.000000      26458.000000
# mean            2.719162                     2.118112          0.886499
# std             1.385055                     1.332950          0.753422
# min             1.000000                     1.000000          0.000000
# 25%             2.000000                     1.000000          0.000000
# 50%             2.000000                     2.000000          1.000000
# 75%             4.000000                     4.000000          1.000000
# max             5.000000                     5.000000          3.000000
#
#        household_children
# count        26458.000000
# mean             0.534583
# std              0.928173
# min              0.000000
# 25%              0.000000
# 50%              0.000000
# 75%              1.000000
# max              3.000000
#
# [8 rows x 24 columns]

# %%
train_feat['test'] = 0
test_feat['test'] = 1

# %%
train_feat = pd.concat([train_feat, test_feat], axis=0)

# %%
train_feat[['behavioral_antiviral_meds', 'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home', 'behavioral_touch_face', 'doctor_recc_h1n1', 'doctor_recc_seasonal', 'chronic_med_condition', 'child_under_6_months', 'health_worker', 'health_insurance']] = train_feat[['behavioral_antiviral_meds', 'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home', 'behavioral_touch_face', 'doctor_recc_h1n1', 'doctor_recc_seasonal', 'chronic_med_condition', 'child_under_6_months', 'health_worker', 'health_insurance']].astype('bool')

# %%
train_feat.head()
# Out:
#    respondent_id  h1n1_concern  h1n1_knowledge  behavioral_antiviral_meds  \
# 0              0           1.0             0.0                      False
# 1              1           3.0             2.0                      False
# 2              2           1.0             1.0                      False
# 3              3           1.0             1.0                      False
# 4              4           2.0             1.0                      False
#
#    behavioral_avoidance  behavioral_face_mask  behavioral_wash_hands  \
# 0                 False                 False                  False
# 1                  True                 False                   True
# 2                  True                 False                  False
# 3                  True                 False                   True
# 4                  True                 False                   True
#
#    behavioral_large_gatherings  behavioral_outside_home  \
# 0                        False                     True
# 1                        False                     True
# 2                        False                    False
# 3                         True                    False
# 4                         True                    False
#
#    behavioral_touch_face  ...  marital_status  rent_or_own  \
# 0                   True  ...     Not Married          Own
# 1                   True  ...     Not Married         Rent
# 2                  False  ...     Not Married          Own
# 3                  False  ...     Not Married         Rent
# 4                   True  ...         Married          Own
#
#     employment_status  hhs_geo_region                census_msa  \
# 0  Not in Labor Force        oxchjgsf                   Non-MSA
# 1            Employed        bhuqouqj  MSA, Not Principle  City
# 2            Employed        qufhixun  MSA, Not Principle  City
# 3  Not in Labor Force        lrircsnp       MSA, Principle City
# 4            Employed        qufhixun  MSA, Not Principle  City
#
#    household_adults  household_children  employment_industry  \
# 0               0.0                 0.0                  NaN
# 1               0.0                 0.0             pxcmvdjn
# 2               2.0                 0.0             rucpziij
# 3               0.0                 0.0                  NaN
# 4               1.0                 0.0             wxleyezf
#
#    employment_occupation  test
# 0                    NaN     0
# 1               xgwztkwe     0
# 2               xtkaffoo     0
# 3                    NaN     0
# 4               emcorrxb     0
#
# [5 rows x 37 columns]

# %%
train_feat.dtypes
# Out:
# respondent_id                    int64
# h1n1_concern                   float64
# h1n1_knowledge                 float64
# behavioral_antiviral_meds         bool
# behavioral_avoidance              bool
# behavioral_face_mask              bool
# behavioral_wash_hands             bool
# behavioral_large_gatherings       bool
# behavioral_outside_home           bool
# behavioral_touch_face             bool
# doctor_recc_h1n1                  bool
# doctor_recc_seasonal              bool
# chronic_med_condition             bool
# child_under_6_months              bool
# health_worker                     bool
# health_insurance                  bool
# opinion_h1n1_vacc_effective    float64
# opinion_h1n1_risk              float64
# opinion_h1n1_sick_from_vacc    float64
# opinion_seas_vacc_effective    float64
# opinion_seas_risk              float64
# opinion_seas_sick_from_vacc    float64
# age_group                       object
# education                       object
# race                            object
# sex                             object
# income_poverty                  object
# marital_status                  object
# rent_or_own                     object
# employment_status               object
# hhs_geo_region                  object
# census_msa                      object
# household_adults               float64
# household_children             float64
# employment_industry             object
# employment_occupation           object
# test                             int64
# dtype: object

# %%
train_lab.head()
# Out:
#    respondent_id  h1n1_vaccine  seasonal_vaccine
# 0              0             0                 0
# 1              1             0                 1
# 2              2             0                 0
# 3              3             0                 1
# 4              4             0                 0

# %% [markdown]
# ## Preparing data

# %%
train_feat.shape
# Out:
# (53415, 37)

# %%
ft.list_primitives()
# Out:
#                                 name         type  dask_compatible  \
# 0          num_consecutive_less_mean  aggregation            False
# 1          max_consecutive_negatives  aggregation            False
# 2                   count_below_mean  aggregation            False
# 3                               mode  aggregation            False
# 4              max_consecutive_zeros  aggregation            False
# 5                                all  aggregation             True
# 6               max_consecutive_true  aggregation            False
# 7       num_consecutive_greater_mean  aggregation            False
# 8                              trend  aggregation            False
# 9                               skew  aggregation            False
# 10                          num_true  aggregation             True
# 11                   time_since_last  aggregation            False
# 12             count_outside_nth_std  aggregation            False
# 13                     n_most_common  aggregation            False
# 14                count_inside_range  aggregation            False
# 15             time_since_last_false  aggregation            False
# 16                           entropy  aggregation            False
# 17                               std  aggregation             True
# 18                  avg_time_between  aggregation            False
# 19                             first  aggregation            False
# 20                              last  aggregation            False
# 21                        num_unique  aggregation             True
# 22                             count  aggregation             True
# 23               count_outside_range  aggregation            False
# 24               time_since_last_max  aggregation            False
# 25                               sum  aggregation             True
# 26         max_consecutive_positives  aggregation            False
# 27             max_consecutive_false  aggregation            False
# 28                               min  aggregation             True
# 29                               any  aggregation             True
# 30               time_since_last_min  aggregation            False
# 31                  time_since_first  aggregation            False
# 32                count_greater_than  aggregation            False
# 33                      percent_true  aggregation             True
# 34                              mean  aggregation             True
# 35                   count_less_than  aggregation            False
# 36                  count_above_mean  aggregation            False
# 37                            median  aggregation            False
# 38              time_since_last_true  aggregation            False
# 39              count_inside_nth_std  aggregation            False
# 40                               max  aggregation             True
# 41                 total_word_length    transform            False
# 42            number_of_unique_words    transform            False
# 43                     is_year_start    transform             True
# 44                           cum_max    transform            False
# 45                               lag    transform            False
# 46                 divide_by_feature    transform             True
# 47                           is_null    transform             True
# 48                           quarter    transform             True
# 49                              sine    transform             True
# 50                             equal    transform             True
# 51                    divide_numeric    transform             True
# 52                   expanding_count    transform            False
# 53          mean_characters_per_word    transform            False
# 54                      is_month_end    transform             True
# 55             modulo_numeric_scalar    transform             True
# 56                     rolling_count    transform            False
# 57                    num_characters    transform             True
# 58                            minute    transform             True
# 59   scalar_subtract_numeric_feature    transform             True
# 60             rolling_outlier_count    transform            False
# 61                      is_in_geobox    transform            False
# 62                            second    transform             True
# 63                             month    transform             True
# 64                      greater_than    transform             True
# 65      greater_than_equal_to_scalar    transform             True
# 66                       numeric_lag    transform            False
# 67     exponential_weighted_variance    transform            False
# 68                     diff_datetime    transform            False
# 69                  multiply_boolean    transform             True
# 70                       rolling_max    transform            False
# 71             num_unique_separators    transform            False
# 72                            cosine    transform             True
# 73                  multiply_numeric    transform             True
# 74                     expanding_max    transform            False
# 75                      equal_scalar    transform             True
# 76            number_of_common_words    transform            False
# 77                 natural_logarithm    transform             True
# 78                    is_month_start    transform             True
# 79             greater_than_equal_to    transform             True
# 80                      rolling_mean    transform            False
# 81                         haversine    transform            False
# 82                  is_quarter_start    transform             True
# 83                 modulo_by_feature    transform             True
# 84                       rolling_std    transform            False
# 85                         num_words    transform             True
# 86                    rate_of_change    transform            False
# 87                   date_to_holiday    transform            False
# 88                           cum_sum    transform            False
# 89           subtract_numeric_scalar    transform             True
# 90                       rolling_min    transform            False
# 91           email_address_to_domain    transform            False
# 92               time_since_previous    transform            False
# 93                               day    transform             True
# 94               greater_than_scalar    transform             True
# 95                     expanding_min    transform            False
# 96                number_of_mentions    transform            False
# 97                    is_quarter_end    transform             True
# 98           multiply_numeric_scalar    transform             True
# 99             two_digit_postal_code    transform             True
# 100                             year    transform             True
# 101                      part_of_day    transform             True
# 102                       time_since    transform             True
# 103                    url_to_domain    transform            False
# 104         multiply_numeric_boolean    transform             True
# 105     exponential_weighted_average    transform            False
# 106                             isin    transform             True
# 107                      day_of_year    transform             True
# 108                        less_than    transform             True
# 109                  expanding_trend    transform            False
# 110                             diff    transform            False
# 111                        not_equal    transform             True
# 112                    rolling_trend    transform            False
# 113               median_word_length    transform            False
# 114                     is_leap_year    transform             True
# 115                  url_to_protocol    transform            False
# 116                         cum_mean    transform            False
# 117                             week    transform             True
# 118                      geomidpoint    transform            False
# 119                      square_root    transform             True
# 120               less_than_equal_to    transform             True
# 121                   expanding_mean    transform            False
# 122             is_free_email_domain    transform            False
# 123              distance_to_holiday    transform            False
# 124                 not_equal_scalar    transform             True
# 125                    expanding_std    transform            False
# 126                       is_weekend    transform             True
# 127                         absolute    transform             True
# 128                          cum_min    transform            False
# 129                      add_numeric    transform             True
# 130                          weekday    transform             True
# 131                         latitude    transform            False
# 132                           negate    transform             True
# 133                       url_to_tld    transform            False
# 134        less_than_equal_to_scalar    transform             True
# 135                 title_word_count    transform            False
# 136                        longitude    transform            False
# 137                 is_working_hours    transform             True
# 138                 subtract_numeric    transform             True
# 139                 upper_case_count    transform            False
# 140        number_of_words_in_quotes    transform            False
# 141                      is_year_end    transform             True
# 142                    days_in_month    transform             True
# 143                               or    transform             True
# 144               add_numeric_scalar    transform             True
# 145                              and    transform             True
# 146            one_digit_postal_code    transform             True
# 147               cityblock_distance    transform            False
# 148                             hour    transform             True
# 149                 less_than_scalar    transform             True
# 150                punctuation_count    transform            False
# 151               number_of_hashtags    transform            False
# 152                          tangent    transform             True
# 153                date_to_time_zone    transform            False
# 154                        cum_count    transform            False
# 155                 whitespace_count    transform            False
# 156         exponential_weighted_std    transform            False
# 157                    is_lunch_time    transform             True
# 158                       percentile    transform            False
# 159            divide_numeric_scalar    transform             True
# 160                              not    transform             True
# 161                     count_string    transform            False
# 162               is_federal_holiday    transform            False
# 163                              age    transform             True
# 164                   modulo_numeric    transform             True
#
#      spark_compatible                                        description  \
# 0               False  Determines the length of the longest subsequen...
# 1               False  Determines the maximum number of consecutive n...
# 2               False  Determines the number of values that are below...
# 3               False       Determines the most commonly repeated value.
# 4               False  Determines the maximum number of consecutive z...
# 5               False     Calculates if all values are 'True' in a list.
# 6               False  Determines the maximum number of consecutive T...
# 7               False  Determines the length of the longest subsequen...
# 8               False        Calculates the trend of a column over time.
# 9               False  Computes the extent to which a distribution di...
# 10              False                Counts the number of `True` values.
# 11              False  Calculates the time elapsed since the last dat...
# 12              False  Determines the number of observations that lie...
# 13              False           Determines the `n` most common elements.
# 14              False  Determines the number of values that fall with...
# 15              False  Calculates the time since the last `False` value.
# 16              False    Calculates the entropy for a categorical column
# 17               True  Computes the dispersion relative to the mean v...
# 18              False  Computes the average number of seconds between...
# 19              False              Determines the first value in a list.
# 20              False               Determines the last value in a list.
# 21               True  Determines the number of distinct values, igno...
# 22               True  Determines the total number of values, excludi...
# 23              False  Determines the number of values that fall outs...
# 24              False  Calculates the time since the maximum value oc...
# 25               True     Calculates the total addition, ignoring `NaN`.
# 26              False  Determines the maximum number of consecutive p...
# 27              False  Determines the maximum number of consecutive F...
# 28               True  Calculates the smallest value, ignoring `NaN` ...
# 29              False       Determines if any value is 'True' in a list.
# 30              False  Calculates the time since the minimum value oc...
# 31              False  Calculates the time elapsed since the first da...
# 32              False  Determines the number of values greater than a...
# 33              False           Determines the percent of `True` values.
# 34               True         Computes the average for a list of values.
# 35              False  Determines the number of values less than a co...
# 36              False  Calculates the number of values that are above...
# 37              False  Determines the middlemost number in a list of ...
# 38              False   Calculates the time since the last `True` value.
# 39              False  Determines the count of observations that lie ...
# 40               True  Calculates the highest value, ignoring `NaN` v...
# 41              False                  Determines the total word length.
# 42              False  Determines the number of unique words in a str...
# 43               True  Determines if a date falls on the start of a y...
# 44              False                 Calculates the cumulative maximum.
# 45              False  Shifts an array of values by a specified numbe...
# 46               True        Divides a scalar by each value in the list.
# 47               True                     Determines if a value is null.
# 48               True  Determines the quarter a datetime column falls...
# 49               True                     Computes the sine of a number.
# 50               True  Determines if values in one list are equal to ...
# 51               True       Performs element-wise division of two lists.
# 52              False  Computes the expanding count of events over a ...
# 53              False  Determines the mean number of characters per w...
# 54               True  Determines the is_month_end attribute of a dat...
# 55               True  Computes the modulo of each element in the lis...
# 56              False  Determines a rolling count of events over a gi...
# 57               True   Calculates the number of characters in a string.
# 58               True        Determines the minutes value of a datetime.
# 59               True  Subtracts each value in the list from a given ...
# 60              False  Determines how many values are outliers over a...
# 61              False  Determines if coordinates are inside a box def...
# 62               True        Determines the seconds value of a datetime.
# 63               True          Determines the month value of a datetime.
# 64              False  Determines if values in one list are greater t...
# 65               True  Determines if values are greater than or equal...
# 66              False  Shifts an array of values by a specified numbe...
# 67              False  Computes the exponentially weighted moving var...
# 68              False  Computes the timedelta between a datetime in a...
# 69              False  Performs element-wise multiplication of two li...
# 70              False  Determines the maximum of entries over a given...
# 71              False        Calculates the number of unique separators.
# 72               True                   Computes the cosine of a number.
# 73               True  Performs element-wise multiplication of two li...
# 74              False  Computes the expanding maximum of events over ...
# 75               True  Determines if values in a list are equal to a ...
# 76              False  Determines the number of common words in a str...
# 77               True        Computes the natural logarithm of a number.
# 78               True  Determines the is_month_start attribute of a d...
# 79               True  Determines if values in one list are greater t...
# 80              False  Calculates the mean of entries over a given wi...
# 81              False  Calculates the approximate haversine distance ...
# 82               True  Determines the is_quarter_start attribute of a...
# 83               True  Computes the modulo of a scalar by each elemen...
# 84              False  Calculates the standard deviation of entries o...
# 85               True  Determines the number of words in a string by ...
# 86              False  Computes the rate of change of a value per sec...
# 87              False  Transforms time of an instance into the holida...
# 88              False                     Calculates the cumulative sum.
# 89               True  Subtracts a scalar from each element in the list.
# 90              False  Determines the minimum of entries over a given...
# 91              False                  Determines the domain of an email
# 92              False  Computes the time since the previous entry in ...
# 93               True   Determines the day of the month from a datetime.
# 94               True  Determines if values are greater than a given ...
# 95              False  Computes the expanding minimum of events over ...
# 96              False     Determines the number of mentions in a string.
# 97               True  Determines the is_quarter_end attribute of a d...
# 98               True   Multiplies each element in the list by a scalar.
# 99               True  Returns the two digit prefix of a given postal...
# 100              True           Determines the year value of a datetime.
# 101              True          Determines the part of day of a datetime.
# 102             False  Calculates time from a value to a specified cu...
# 103             False                    Determines the domain of a url.
# 104             False  Performs element-wise multiplication of a nume...
# 105             False  Computes the exponentially weighted moving ave...
# 106              True  Determines whether a value is present in a pro...
# 107              True  Determines the ordinal day of the year from th...
# 108              True  Determines if values in one list are less than...
# 109             False  Computes the expanding trend for events over a...
# 110             False  Computes the difference between the value in a...
# 111             False  Determines if values in one list are not equal...
# 112             False  Calculates the trend of a given window of entr...
# 113             False                 Determines the median word length.
# 114              True  Determines the is_leap_year attribute of a dat...
# 115             False  Determines the protocol (http or https) of a url.
# 116             False                    Calculates the cumulative mean.
# 117              True   Determines the week of the year from a datetime.
# 118             False  Determines the geographic center of two coordi...
# 119              True              Computes the square root of a number.
# 120              True  Determines if values in one list are less than...
# 121             False  Computes the expanding mean of events over a g...
# 122             False  Determines if an email address is from a free ...
# 123             False  Computes the number of days before or after a ...
# 124              True  Determines if values in a list are not equal t...
# 125             False  Computes the expanding standard deviation for ...
# 126              True           Determines if a date falls on a weekend.
# 127              True           Computes the absolute value of a number.
# 128             False                 Calculates the cumulative minimum.
# 129              True       Performs element-wise addition of two lists.
# 130              True    Determines the day of the week from a datetime.
# 131             False  Returns the first tuple value in a list of Lat...
# 132              True                           Negates a numeric value.
# 133             False          Determines the top level domain of a url.
# 134              True  Determines if values are less than or equal to...
# 135             False  Determines the number of title words in a string.
# 136             False  Returns the second tuple value in a list of La...
# 137              True  Determines if a datetime falls during working ...
# 138             False    Performs element-wise subtraction of two lists.
# 139             False  Calculates the number of upper case letters in...
# 140             False  Determines the number of words in quotes in a ...
# 141              True   Determines if a date falls on the end of a year.
# 142              True   Determines the day of the month from a datetime.
# 143              True     Performs element-wise logical OR of two lists.
# 144              True           Adds a scalar to each value in the list.
# 145              True    Performs element-wise logical AND of two lists.
# 146              True  Returns the one digit prefix of a given postal...
# 147             False  Calculates the distance between points in a ci...
# 148              True           Determines the hour value of a datetime.
# 149              True  Determines if values are less than a given sca...
# 150             False  Determines number of punctuation characters in...
# 151             False     Determines the number of hashtags in a string.
# 152              True                  Computes the tangent of a number.
# 153             False             Determines the timezone of a datetime.
# 154             False                   Calculates the cumulative count.
# 155             False      Calculates number of whitespaces in a string.
# 156             False  Computes the exponentially weighted moving sta...
# 157              True  Determines if a datetime falls during configur...
# 158             False  Determines the percentile rank for each value ...
# 159              True      Divides each element in the list by a scalar.
# 160              True                           Negates a boolean value.
# 161             False  Determines how many times a given string shows...
# 162             False  Determines if a given datetime is a federal ho...
# 163             False  Calculates the age in years as a floating poin...
# 164              True         Performs element-wise modulo of two lists.
#
#                                           valid_inputs  \
# 0         <ColumnSchema (Semantic Tags = ['numeric'])>
# 1    <ColumnSchema (Logical Type = Integer)>, <Colu...
# 2         <ColumnSchema (Semantic Tags = ['numeric'])>
# 3        <ColumnSchema (Semantic Tags = ['category'])>
# 4    <ColumnSchema (Logical Type = Integer)>, <Colu...
# 5    <ColumnSchema (Logical Type = Boolean)>, <Colu...
# 6              <ColumnSchema (Logical Type = Boolean)>
# 7         <ColumnSchema (Semantic Tags = ['numeric'])>
# 8    <ColumnSchema (Logical Type = Datetime) (Seman...
# 9         <ColumnSchema (Semantic Tags = ['numeric'])>
# 10   <ColumnSchema (Logical Type = Boolean)>, <Colu...
# 11   <ColumnSchema (Logical Type = Datetime) (Seman...
# 12        <ColumnSchema (Semantic Tags = ['numeric'])>
# 13       <ColumnSchema (Semantic Tags = ['category'])>
# 14        <ColumnSchema (Semantic Tags = ['numeric'])>
# 15   <ColumnSchema (Logical Type = Boolean)>, <Colu...
# 16       <ColumnSchema (Semantic Tags = ['category'])>
# 17        <ColumnSchema (Semantic Tags = ['numeric'])>
# 18   <ColumnSchema (Logical Type = Datetime) (Seman...
# 19                                      <ColumnSchema>
# 20                                      <ColumnSchema>
# 21       <ColumnSchema (Semantic Tags = ['category'])>
# 22          <ColumnSchema (Semantic Tags = ['index'])>
# 23        <ColumnSchema (Semantic Tags = ['numeric'])>
# 24   <ColumnSchema (Logical Type = Datetime) (Seman...
# 25        <ColumnSchema (Semantic Tags = ['numeric'])>
# 26   <ColumnSchema (Logical Type = Integer)>, <Colu...
# 27             <ColumnSchema (Logical Type = Boolean)>
# 28        <ColumnSchema (Semantic Tags = ['numeric'])>
# 29   <ColumnSchema (Logical Type = Boolean)>, <Colu...
# 30   <ColumnSchema (Logical Type = Datetime) (Seman...
# 31   <ColumnSchema (Logical Type = Datetime) (Seman...
# 32        <ColumnSchema (Semantic Tags = ['numeric'])>
# 33   <ColumnSchema (Logical Type = Boolean)>, <Colu...
# 34        <ColumnSchema (Semantic Tags = ['numeric'])>
# 35        <ColumnSchema (Semantic Tags = ['numeric'])>
# 36        <ColumnSchema (Semantic Tags = ['numeric'])>
# 37        <ColumnSchema (Semantic Tags = ['numeric'])>
# 38   <ColumnSchema (Logical Type = Boolean)>, <Colu...
# 39        <ColumnSchema (Semantic Tags = ['numeric'])>
# 40        <ColumnSchema (Semantic Tags = ['numeric'])>
# 41     <ColumnSchema (Logical Type = NaturalLanguage)>
# 42     <ColumnSchema (Logical Type = NaturalLanguage)>
# 43            <ColumnSchema (Logical Type = Datetime)>
# 44        <ColumnSchema (Semantic Tags = ['numeric'])>
# 45   <ColumnSchema (Semantic Tags = ['time_index'])...
# 46        <ColumnSchema (Semantic Tags = ['numeric'])>
# 47                                      <ColumnSchema>
# 48            <ColumnSchema (Logical Type = Datetime)>
# 49        <ColumnSchema (Semantic Tags = ['numeric'])>
# 50                                      <ColumnSchema>
# 51        <ColumnSchema (Semantic Tags = ['numeric'])>
# 52   <ColumnSchema (Logical Type = Datetime) (Seman...
# 53     <ColumnSchema (Logical Type = NaturalLanguage)>
# 54            <ColumnSchema (Logical Type = Datetime)>
# 55        <ColumnSchema (Semantic Tags = ['numeric'])>
# 56   <ColumnSchema (Logical Type = Datetime) (Seman...
# 57     <ColumnSchema (Logical Type = NaturalLanguage)>
# 58            <ColumnSchema (Logical Type = Datetime)>
# 59        <ColumnSchema (Semantic Tags = ['numeric'])>
# 60   <ColumnSchema (Logical Type = Datetime) (Seman...
# 61             <ColumnSchema (Logical Type = LatLong)>
# 62            <ColumnSchema (Logical Type = Datetime)>
# 63            <ColumnSchema (Logical Type = Datetime)>
# 64   <ColumnSchema (Logical Type = Datetime)>, <Col...
# 65        <ColumnSchema (Semantic Tags = ['numeric'])>
# 66   <ColumnSchema (Semantic Tags = ['time_index'])...
# 67        <ColumnSchema (Semantic Tags = ['numeric'])>
# 68            <ColumnSchema (Logical Type = Datetime)>
# 69   <ColumnSchema (Logical Type = Boolean)>, <Colu...
# 70   <ColumnSchema (Logical Type = Datetime) (Seman...
# 71     <ColumnSchema (Logical Type = NaturalLanguage)>
# 72        <ColumnSchema (Semantic Tags = ['numeric'])>
# 73        <ColumnSchema (Semantic Tags = ['numeric'])>
# 74   <ColumnSchema (Logical Type = Datetime) (Seman...
# 75                                      <ColumnSchema>
# 76     <ColumnSchema (Logical Type = NaturalLanguage)>
# 77        <ColumnSchema (Semantic Tags = ['numeric'])>
# 78            <ColumnSchema (Logical Type = Datetime)>
# 79   <ColumnSchema (Logical Type = Datetime)>, <Col...
# 80   <ColumnSchema (Logical Type = Datetime) (Seman...
# 81             <ColumnSchema (Logical Type = LatLong)>
# 82            <ColumnSchema (Logical Type = Datetime)>
# 83        <ColumnSchema (Semantic Tags = ['numeric'])>
# 84   <ColumnSchema (Logical Type = Datetime) (Seman...
# 85     <ColumnSchema (Logical Type = NaturalLanguage)>
# 86   <ColumnSchema (Logical Type = Datetime) (Seman...
# 87            <ColumnSchema (Logical Type = Datetime)>
# 88        <ColumnSchema (Semantic Tags = ['numeric'])>
# 89        <ColumnSchema (Semantic Tags = ['numeric'])>
# 90   <ColumnSchema (Logical Type = Datetime) (Seman...
# 91        <ColumnSchema (Logical Type = EmailAddress)>
# 92   <ColumnSchema (Logical Type = Datetime) (Seman...
# 93            <ColumnSchema (Logical Type = Datetime)>
# 94        <ColumnSchema (Semantic Tags = ['numeric'])>
# 95   <ColumnSchema (Logical Type = Datetime) (Seman...
# 96     <ColumnSchema (Logical Type = NaturalLanguage)>
# 97            <ColumnSchema (Logical Type = Datetime)>
# 98        <ColumnSchema (Semantic Tags = ['numeric'])>
# 99          <ColumnSchema (Logical Type = PostalCode)>
# 100           <ColumnSchema (Logical Type = Datetime)>
# 101           <ColumnSchema (Logical Type = Datetime)>
# 102           <ColumnSchema (Logical Type = Datetime)>
# 103                <ColumnSchema (Logical Type = URL)>
# 104  <ColumnSchema (Logical Type = BooleanNullable)...
# 105       <ColumnSchema (Semantic Tags = ['numeric'])>
# 106                                     <ColumnSchema>
# 107           <ColumnSchema (Logical Type = Datetime)>
# 108  <ColumnSchema (Logical Type = Datetime)>, <Col...
# 109  <ColumnSchema (Logical Type = Datetime) (Seman...
# 110       <ColumnSchema (Semantic Tags = ['numeric'])>
# 111                                     <ColumnSchema>
# 112  <ColumnSchema (Logical Type = Datetime) (Seman...
# 113    <ColumnSchema (Logical Type = NaturalLanguage)>
# 114           <ColumnSchema (Logical Type = Datetime)>
# 115                <ColumnSchema (Logical Type = URL)>
# 116       <ColumnSchema (Semantic Tags = ['numeric'])>
# 117           <ColumnSchema (Logical Type = Datetime)>
# 118            <ColumnSchema (Logical Type = LatLong)>
# 119       <ColumnSchema (Semantic Tags = ['numeric'])>
# 120  <ColumnSchema (Logical Type = Datetime)>, <Col...
# 121  <ColumnSchema (Logical Type = Datetime) (Seman...
# 122       <ColumnSchema (Logical Type = EmailAddress)>
# 123           <ColumnSchema (Logical Type = Datetime)>
# 124                                     <ColumnSchema>
# 125  <ColumnSchema (Logical Type = Datetime) (Seman...
# 126           <ColumnSchema (Logical Type = Datetime)>
# 127       <ColumnSchema (Semantic Tags = ['numeric'])>
# 128       <ColumnSchema (Semantic Tags = ['numeric'])>
# 129       <ColumnSchema (Semantic Tags = ['numeric'])>
# 130           <ColumnSchema (Logical Type = Datetime)>
# 131            <ColumnSchema (Logical Type = LatLong)>
# 132       <ColumnSchema (Semantic Tags = ['numeric'])>
# 133                <ColumnSchema (Logical Type = URL)>
# 134       <ColumnSchema (Semantic Tags = ['numeric'])>
# 135    <ColumnSchema (Logical Type = NaturalLanguage)>
# 136            <ColumnSchema (Logical Type = LatLong)>
# 137           <ColumnSchema (Logical Type = Datetime)>
# 138       <ColumnSchema (Semantic Tags = ['numeric'])>
# 139    <ColumnSchema (Logical Type = NaturalLanguage)>
# 140    <ColumnSchema (Logical Type = NaturalLanguage)>
# 141           <ColumnSchema (Logical Type = Datetime)>
# 142           <ColumnSchema (Logical Type = Datetime)>
# 143  <ColumnSchema (Logical Type = Boolean)>, <Colu...
# 144       <ColumnSchema (Semantic Tags = ['numeric'])>
# 145  <ColumnSchema (Logical Type = Boolean)>, <Colu...
# 146         <ColumnSchema (Logical Type = PostalCode)>
# 147            <ColumnSchema (Logical Type = LatLong)>
# 148           <ColumnSchema (Logical Type = Datetime)>
# 149       <ColumnSchema (Semantic Tags = ['numeric'])>
# 150    <ColumnSchema (Logical Type = NaturalLanguage)>
# 151    <ColumnSchema (Logical Type = NaturalLanguage)>
# 152       <ColumnSchema (Semantic Tags = ['numeric'])>
# 153           <ColumnSchema (Logical Type = Datetime)>
# 154  <ColumnSchema (Semantic Tags = ['foreign_key']...
# 155    <ColumnSchema (Logical Type = NaturalLanguage)>
# 156       <ColumnSchema (Semantic Tags = ['numeric'])>
# 157           <ColumnSchema (Logical Type = Datetime)>
# 158       <ColumnSchema (Semantic Tags = ['numeric'])>
# 159       <ColumnSchema (Semantic Tags = ['numeric'])>
# 160  <ColumnSchema (Logical Type = Boolean)>, <Colu...
# 161    <ColumnSchema (Logical Type = NaturalLanguage)>
# 162           <ColumnSchema (Logical Type = Datetime)>
# 163  <ColumnSchema (Logical Type = Datetime) (Seman...
# 164       <ColumnSchema (Semantic Tags = ['numeric'])>
#
#                                            return_type
# 0    <ColumnSchema (Logical Type = IntegerNullable)...
# 1    <ColumnSchema (Logical Type = Integer) (Semant...
# 2    <ColumnSchema (Logical Type = IntegerNullable)...
# 3                                                 None
# 4    <ColumnSchema (Logical Type = Integer) (Semant...
# 5              <ColumnSchema (Logical Type = Boolean)>
# 6    <ColumnSchema (Logical Type = Integer) (Semant...
# 7    <ColumnSchema (Logical Type = IntegerNullable)...
# 8         <ColumnSchema (Semantic Tags = ['numeric'])>
# 9         <ColumnSchema (Semantic Tags = ['numeric'])>
# 10   <ColumnSchema (Logical Type = IntegerNullable)...
# 11   <ColumnSchema (Logical Type = Double) (Semanti...
# 12   <ColumnSchema (Logical Type = Integer) (Semant...
# 13                                                None
# 14   <ColumnSchema (Logical Type = IntegerNullable)...
# 15   <ColumnSchema (Logical Type = Double) (Semanti...
# 16        <ColumnSchema (Semantic Tags = ['numeric'])>
# 17        <ColumnSchema (Semantic Tags = ['numeric'])>
# 18   <ColumnSchema (Logical Type = Double) (Semanti...
# 19                                                None
# 20                                                None
# 21   <ColumnSchema (Logical Type = IntegerNullable)...
# 22   <ColumnSchema (Logical Type = IntegerNullable)...
# 23   <ColumnSchema (Logical Type = IntegerNullable)...
# 24   <ColumnSchema (Logical Type = Double) (Semanti...
# 25        <ColumnSchema (Semantic Tags = ['numeric'])>
# 26   <ColumnSchema (Logical Type = Integer) (Semant...
# 27   <ColumnSchema (Logical Type = Integer) (Semant...
# 28        <ColumnSchema (Semantic Tags = ['numeric'])>
# 29             <ColumnSchema (Logical Type = Boolean)>
# 30   <ColumnSchema (Logical Type = Double) (Semanti...
# 31   <ColumnSchema (Logical Type = Double) (Semanti...
# 32   <ColumnSchema (Logical Type = Integer) (Semant...
# 33   <ColumnSchema (Logical Type = Double) (Semanti...
# 34        <ColumnSchema (Semantic Tags = ['numeric'])>
# 35   <ColumnSchema (Logical Type = Integer) (Semant...
# 36   <ColumnSchema (Logical Type = IntegerNullable)...
# 37        <ColumnSchema (Semantic Tags = ['numeric'])>
# 38   <ColumnSchema (Logical Type = Double) (Semanti...
# 39   <ColumnSchema (Logical Type = Integer) (Semant...
# 40        <ColumnSchema (Semantic Tags = ['numeric'])>
# 41   <ColumnSchema (Logical Type = Double) (Semanti...
# 42   <ColumnSchema (Logical Type = IntegerNullable)...
# 43     <ColumnSchema (Logical Type = BooleanNullable)>
# 44        <ColumnSchema (Semantic Tags = ['numeric'])>
# 45                                                None
# 46        <ColumnSchema (Semantic Tags = ['numeric'])>
# 47             <ColumnSchema (Logical Type = Boolean)>
# 48   <ColumnSchema (Logical Type = Ordinal: [1, 2, ...
# 49   <ColumnSchema (Logical Type = Double) (Semanti...
# 50     <ColumnSchema (Logical Type = BooleanNullable)>
# 51        <ColumnSchema (Semantic Tags = ['numeric'])>
# 52   <ColumnSchema (Logical Type = IntegerNullable)...
# 53   <ColumnSchema (Logical Type = Double) (Semanti...
# 54     <ColumnSchema (Logical Type = BooleanNullable)>
# 55        <ColumnSchema (Semantic Tags = ['numeric'])>
# 56   <ColumnSchema (Logical Type = Double) (Semanti...
# 57        <ColumnSchema (Semantic Tags = ['numeric'])>
# 58   <ColumnSchema (Logical Type = Ordinal: [0, 1, ...
# 59        <ColumnSchema (Semantic Tags = ['numeric'])>
# 60   <ColumnSchema (Logical Type = Double) (Semanti...
# 61     <ColumnSchema (Logical Type = BooleanNullable)>
# 62   <ColumnSchema (Logical Type = Ordinal: [0, 1, ...
# 63   <ColumnSchema (Logical Type = Ordinal: [1, 2, ...
# 64     <ColumnSchema (Logical Type = BooleanNullable)>
# 65     <ColumnSchema (Logical Type = BooleanNullable)>
# 66        <ColumnSchema (Semantic Tags = ['numeric'])>
# 67   <ColumnSchema (Logical Type = Double) (Semanti...
# 68           <ColumnSchema (Logical Type = Timedelta)>
# 69     <ColumnSchema (Logical Type = BooleanNullable)>
# 70   <ColumnSchema (Logical Type = Double) (Semanti...
# 71   <ColumnSchema (Logical Type = IntegerNullable)...
# 72   <ColumnSchema (Logical Type = Double) (Semanti...
# 73        <ColumnSchema (Semantic Tags = ['numeric'])>
# 74        <ColumnSchema (Semantic Tags = ['numeric'])>
# 75     <ColumnSchema (Logical Type = BooleanNullable)>
# 76   <ColumnSchema (Logical Type = IntegerNullable)...
# 77   <ColumnSchema (Logical Type = Double) (Semanti...
# 78     <ColumnSchema (Logical Type = BooleanNullable)>
# 79     <ColumnSchema (Logical Type = BooleanNullable)>
# 80   <ColumnSchema (Logical Type = Double) (Semanti...
# 81        <ColumnSchema (Semantic Tags = ['numeric'])>
# 82     <ColumnSchema (Logical Type = BooleanNullable)>
# 83        <ColumnSchema (Semantic Tags = ['numeric'])>
# 84   <ColumnSchema (Logical Type = Double) (Semanti...
# 85        <ColumnSchema (Semantic Tags = ['numeric'])>
# 86   <ColumnSchema (Logical Type = Double) (Semanti...
# 87   <ColumnSchema (Logical Type = Categorical) (Se...
# 88        <ColumnSchema (Semantic Tags = ['numeric'])>
# 89        <ColumnSchema (Semantic Tags = ['numeric'])>
# 90   <ColumnSchema (Logical Type = Double) (Semanti...
# 91   <ColumnSchema (Logical Type = Categorical) (Se...
# 92        <ColumnSchema (Semantic Tags = ['numeric'])>
# 93   <ColumnSchema (Logical Type = Ordinal: [1, 2, ...
# 94     <ColumnSchema (Logical Type = BooleanNullable)>
# 95        <ColumnSchema (Semantic Tags = ['numeric'])>
# 96   <ColumnSchema (Logical Type = IntegerNullable)...
# 97     <ColumnSchema (Logical Type = BooleanNullable)>
# 98        <ColumnSchema (Semantic Tags = ['numeric'])>
# 99   <ColumnSchema (Logical Type = Categorical) (Se...
# 100  <ColumnSchema (Logical Type = Ordinal: [1, 2, ...
# 101  <ColumnSchema (Logical Type = Categorical) (Se...
# 102       <ColumnSchema (Semantic Tags = ['numeric'])>
# 103  <ColumnSchema (Logical Type = Categorical) (Se...
# 104       <ColumnSchema (Semantic Tags = ['numeric'])>
# 105  <ColumnSchema (Logical Type = Double) (Semanti...
# 106            <ColumnSchema (Logical Type = Boolean)>
# 107  <ColumnSchema (Logical Type = Ordinal: [1, 2, ...
# 108    <ColumnSchema (Logical Type = BooleanNullable)>
# 109  <ColumnSchema (Logical Type = Double) (Semanti...
# 110       <ColumnSchema (Semantic Tags = ['numeric'])>
# 111    <ColumnSchema (Logical Type = BooleanNullable)>
# 112  <ColumnSchema (Logical Type = Double) (Semanti...
# 113  <ColumnSchema (Logical Type = Double) (Semanti...
# 114    <ColumnSchema (Logical Type = BooleanNullable)>
# 115  <ColumnSchema (Logical Type = Categorical) (Se...
# 116       <ColumnSchema (Semantic Tags = ['numeric'])>
# 117  <ColumnSchema (Logical Type = Ordinal: [1, 2, ...
# 118            <ColumnSchema (Logical Type = LatLong)>
# 119  <ColumnSchema (Logical Type = Double) (Semanti...
# 120    <ColumnSchema (Logical Type = BooleanNullable)>
# 121  <ColumnSchema (Logical Type = Double) (Semanti...
# 122    <ColumnSchema (Logical Type = BooleanNullable)>
# 123       <ColumnSchema (Semantic Tags = ['numeric'])>
# 124    <ColumnSchema (Logical Type = BooleanNullable)>
# 125  <ColumnSchema (Logical Type = Double) (Semanti...
# 126    <ColumnSchema (Logical Type = BooleanNullable)>
# 127       <ColumnSchema (Semantic Tags = ['numeric'])>
# 128       <ColumnSchema (Semantic Tags = ['numeric'])>
# 129       <ColumnSchema (Semantic Tags = ['numeric'])>
# 130  <ColumnSchema (Logical Type = Ordinal: [0, 1, ...
# 131       <ColumnSchema (Semantic Tags = ['numeric'])>
# 132       <ColumnSchema (Semantic Tags = ['numeric'])>
# 133  <ColumnSchema (Logical Type = Categorical) (Se...
# 134    <ColumnSchema (Logical Type = BooleanNullable)>
# 135  <ColumnSchema (Logical Type = IntegerNullable)...
# 136       <ColumnSchema (Semantic Tags = ['numeric'])>
# 137    <ColumnSchema (Logical Type = BooleanNullable)>
# 138       <ColumnSchema (Semantic Tags = ['numeric'])>
# 139  <ColumnSchema (Logical Type = IntegerNullable)...
# 140  <ColumnSchema (Logical Type = IntegerNullable)...
# 141    <ColumnSchema (Logical Type = BooleanNullable)>
# 142  <ColumnSchema (Logical Type = Ordinal: [1, 2, ...
# 143    <ColumnSchema (Logical Type = BooleanNullable)>
# 144       <ColumnSchema (Semantic Tags = ['numeric'])>
# 145    <ColumnSchema (Logical Type = BooleanNullable)>
# 146  <ColumnSchema (Logical Type = Categorical) (Se...
# 147  <ColumnSchema (Logical Type = Double) (Semanti...
# 148  <ColumnSchema (Logical Type = Ordinal: [0, 1, ...
# 149    <ColumnSchema (Logical Type = BooleanNullable)>
# 150  <ColumnSchema (Logical Type = IntegerNullable)...
# 151  <ColumnSchema (Logical Type = IntegerNullable)...
# 152  <ColumnSchema (Logical Type = Double) (Semanti...
# 153  <ColumnSchema (Logical Type = Categorical) (Se...
# 154  <ColumnSchema (Logical Type = IntegerNullable)...
# 155  <ColumnSchema (Logical Type = IntegerNullable)...
# 156  <ColumnSchema (Logical Type = Double) (Semanti...
# 157    <ColumnSchema (Logical Type = BooleanNullable)>
# 158       <ColumnSchema (Semantic Tags = ['numeric'])>
# 159       <ColumnSchema (Semantic Tags = ['numeric'])>
# 160    <ColumnSchema (Logical Type = BooleanNullable)>
# 161  <ColumnSchema (Logical Type = IntegerNullable)...
# 162    <ColumnSchema (Logical Type = BooleanNullable)>
# 163  <ColumnSchema (Logical Type = AgeFractional) (...
# 164       <ColumnSchema (Semantic Tags = ['numeric'])>

# %%
es = ft.EntitySet(id = 'train')
es = es.add_dataframe(
      dataframe_name="data",
      dataframe=train_feat,
      index=None,
)
# Out:
# C:\Users\koren\AppData\Roaming\Python\Python39\site-packages\featuretools\entityset\entityset.py:1890: UserWarning: Using first column as index. To change this, specify the index parameter
#   warnings.warn(

# %%
agg_primitives = ['entropy', 'n_most_common', 'count_greater_than', 'any', 'all', 'num_true', 'median', 'num_consecutive_greater_mean', 'count_inside_nth_std', 'percent_true']
trans_primitives = ['cum_sum', 'cum_max', 'cum_min', 'diff', 'percentile', 'multiply_numeric', 'add_numeric', 'multiply_boolean', 'multiply_numeric_boolean', 'and', 'or']

dfs_feat, dfs_defs = ft.dfs(
    entityset=es,
    target_dataframe_name = 'data',
    trans_primitives=trans_primitives,
    agg_primitives=agg_primitives, 
    max_features=2000,
    chunk_size=4000,
    verbose=True,                            
    max_depth=3,
    n_jobs=-1,
    ignore_columns={'data': ['respondent_id', 'test']}
)
# Out:
# C:\Users\koren\AppData\Roaming\Python\Python39\site-packages\featuretools\synthesis\deep_feature_synthesis.py:170: UserWarning: Only one dataframe in entityset, changing max_depth to 1 since deeper features cannot be created
#   warnings.warn(
# C:\Users\koren\AppData\Roaming\Python\Python39\site-packages\featuretools\synthesis\dfs.py:321: UnusedPrimitiveWarning: Some specified primitives were not used during DFS:
#   agg_primitives: ['all', 'any', 'count_greater_than', 'count_inside_nth_std', 'entropy', 'median', 'n_most_common', 'num_consecutive_greater_mean', 'num_true', 'percent_true']
# This may be caused by a using a value of max_depth that is too small, not setting interesting values, or it may indicate no compatible columns for the primitive were found in the data. If the DFS call contained multiple instances of a primitive in the list above, none of them were used.
#   warnings.warn(warning_msg, UnusedPrimitiveWarning)
# Built 539 features
# EntitySet scattered to 8 workers in 26 seconds
# Elapsed: 00:25 | Progress: 100%|███████████████████████████████████████████████████████████████████████████████████████

# %%
dfs_feat = pd.concat([train_feat[['respondent_id', 'test']], dfs_feat], axis=1)

# %%
dfs_feat.head()
# Out:
#    respondent_id  test  h1n1_concern  h1n1_knowledge  \
# 0              0     0             1               0
# 1              1     0             3               2
# 2              2     0             1               1
# 3              3     0             1               1
# 4              4     0             2               1
#
#    behavioral_antiviral_meds  behavioral_avoidance  behavioral_face_mask  \
# 0                      False                 False                 False
# 1                      False                  True                 False
# 2                      False                  True                 False
# 3                      False                  True                 False
# 4                      False                  True                 False
#
#    behavioral_wash_hands  behavioral_large_gatherings  \
# 0                  False                        False
# 1                   True                        False
# 2                  False                        False
# 3                   True                         True
# 4                   True                         True
#
#    behavioral_outside_home  ...  PERCENTILE(h1n1_concern)  \
# 0                     True  ...                  0.275198
# 1                     True  ...                  0.914413
# 2                    False  ...                  0.275198
# 3                    False  ...                  0.275198
# 4                    False  ...                  0.628602
#
#    PERCENTILE(h1n1_knowledge)  PERCENTILE(household_adults)  \
# 0                    0.046533                      0.151112
# 1                    0.821342                      0.151112
# 2                    0.367866                      0.903704
# 3                    0.367866                      0.151112
# 4                    0.367866                      0.576170
#
#    PERCENTILE(household_children)  PERCENTILE(opinion_h1n1_risk)  \
# 0                         0.35175                       0.155251
# 1                         0.35175                       0.833552
# 2                         0.35175                       0.155251
# 3                         0.35175                       0.710031
# 4                         0.35175                       0.710031
#
#    PERCENTILE(opinion_h1n1_sick_from_vacc)  \
# 0                                 0.514512
# 1                                 0.805936
# 2                                 0.170330
# 3                                 0.958819
# 4                                 0.514512
#
#    PERCENTILE(opinion_h1n1_vacc_effective)  PERCENTILE(opinion_seas_risk)  \
# 0                                 0.194239                       0.113679
# 1                                 0.864801                       0.399345
# 2                                 0.194239                       0.113679
# 3                                 0.194239                       0.743712
# 4                                 0.194239                       0.113679
#
#    PERCENTILE(opinion_seas_sick_from_vacc)  \
# 0                                 0.595116
# 1                                 0.839525
# 2                                 0.595116
# 3                                 0.223924
# 4                                 0.839525
#
#    PERCENTILE(opinion_seas_vacc_effective)
# 0                                 0.087970
# 1                                 0.399345
# 2                                 0.399345
# 3                                 0.809823
# 4                                 0.154892
#
# [5 rows x 541 columns]

# %%
dfs_feat = selection.remove_low_information_features(dfs_feat)
dfs_feat = selection.remove_highly_null_features(dfs_feat)
dfs_feat = selection.remove_single_value_features(dfs_feat)
dfs_feat = dfs_feat.drop(columns=[col for col in dfs_feat.columns if 'inf' in [str(i) for i in dfs_feat[col].tolist()]])

# %%
X = dfs_feat[dfs_feat['test']==0].drop(['respondent_id', 'test'], axis=1)
X_test = dfs_feat[dfs_feat['test']==1].drop(['respondent_id', 'test'], axis=1)
y = train_lab.drop('respondent_id', axis=1)

# %%
y.iloc[:,0].value_counts()
# Out:
# 0    21033
# 1     5674
# Name: h1n1_vaccine, dtype: int64

# %%
y.iloc[:,1].value_counts()
# Out:
# 0    14272
# 1    12435
# Name: seasonal_vaccine, dtype: int64

# %%
skf = StratifiedKFold(5, random_state=42, shuffle=True)

# %%
df_metrics = {'method': [], 'roc_auc: h1n1_vaccine':[], 'roc_auc: seasonal_vaccine':[], 'shape': [], 'time': []}

# %% [markdown]
# ## Defining functions

# %%
def function_class_pipeline(classifier):
    class_pipeline = Pipeline([
    ('classifier', classifier)
    ])
    return class_pipeline

# %%
def function_cross_val_score(class_pipeline, X, y, skf):
    scores = cross_val_score(
        class_pipeline, X, y, 
        cv=skf, scoring='roc_auc'
    )
    return scores

# %%
def function_add_metrics(method, scores_h1n1, scores_seasonal, time, X):
    df_metrics['method'] += [method]
    df_metrics['roc_auc: h1n1_vaccine'] += [round(scores_h1n1.mean(), 3)]
    df_metrics['roc_auc: seasonal_vaccine'] += [round(scores_seasonal.mean(), 3)]
    df_metrics['shape'] += [X.shape[1]]
    df_metrics['time'] += [round(time, 3)]
    
    return df_metrics

# %% [markdown]
# ## BaseLines

# %% [markdown]
# ### BaseLine LGBM without featuretools and oversampling

# %%
# Time measurement
start_time = time.time()

# Preparation pipeline
prepare_pipeline_base1 = Pipeline([
    ('label-encoder', JamesSteinEncoder()),
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', RobustScaler())
])

X_clean = train_feat[train_feat['test']==0].drop(['respondent_id', 'test'], axis=1)

X_prep_lgbm_wft_h1n1 = prepare_pipeline_base1.fit_transform(X_clean, y.iloc[:,0])
X_prep_lgbm_wft_seasonal = prepare_pipeline_base1.fit_transform(X_clean, y.iloc[:,1])

# Classification pipeline LightGBM
lgbm_pipeline_base_wft = function_class_pipeline(LGBMClassifier(max_depth=5))

# Cross-validated roc auc
scores_h1n1 = function_cross_val_score(lgbm_pipeline_base_wft, X_prep_lgbm_wft_h1n1, y.iloc[:,0], skf)
scores_seasonal = function_cross_val_score(lgbm_pipeline_base_wft, X_prep_lgbm_wft_seasonal, y.iloc[:,1], skf)

end_time = time.time() - start_time

print('Cross-validated ROC_AUC for h1n1: %0.3f +/- %0.3f' % (scores_h1n1.mean(), scores_h1n1.std()))
print('Cross-validated ROC_AUC for seasonal: %0.3f +/- %0.3f' % (scores_seasonal.mean(), scores_seasonal.std()))

# Add metrics to dataframe
df_metrics = function_add_metrics('lgbm_pipeline_base_without_featuretools', scores_h1n1, scores_seasonal, end_time, X_prep_lgbm_wft_h1n1)
# Out:
# Cross-validated ROC_AUC for h1n1: 0.828 +/- 0.006
# Cross-validated ROC_AUC for seasonal: 0.856 +/- 0.004

# %% [markdown]
# ### BaseLine LGBM with featuretools

# %%
# Time measurement
start_time = time.time()

# Preparation pipeline
prepare_pipeline_base1 = Pipeline([
    ('label-encoder', JamesSteinEncoder()),
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

X_prep_lgbm_h1n1 = prepare_pipeline_base1.fit_transform(X, y.iloc[:,0])
X_prep_lgbm_seasonal = prepare_pipeline_base1.fit_transform(X, y.iloc[:,1])

# Oversampling
oversample_h1n1 = SMOTE(random_state=5)
oversample_seasonal = SMOTE(random_state=5)

X_prep_lgbm_h1n1, y_h1n1 = oversample_h1n1.fit_resample(X_prep_lgbm_h1n1, y.iloc[:,0])
X_prep_lgbm_seasonal, y_seasonal = oversample_seasonal.fit_resample(X_prep_lgbm_seasonal, y.iloc[:,1])

# Classification pipeline LightGBM
lgbm_pipeline_base = function_class_pipeline(LGBMClassifier(max_depth=5))

# Cross-validated roc auc
scores_h1n1 = function_cross_val_score(lgbm_pipeline_base, X_prep_lgbm_h1n1, y_h1n1, skf)
scores_seasonal = function_cross_val_score(lgbm_pipeline_base, X_prep_lgbm_seasonal, y_seasonal, skf)

end_time = time.time() - start_time

print('Cross-validated ROC_AUC for h1n1: %0.3f +/- %0.3f' % (scores_h1n1.mean(), scores_h1n1.std()))
print('Cross-validated ROC_AUC for seasonal: %0.3f +/- %0.3f' % (scores_seasonal.mean(), scores_seasonal.std()))

# Add metrics to dataframe
df_metrics = function_add_metrics('lgbm_pipeline_base', scores_h1n1, scores_seasonal, end_time, X_prep_lgbm_h1n1)
# Out:
# Cross-validated ROC_AUC for h1n1: 0.954 +/- 0.002
# Cross-validated ROC_AUC for seasonal: 0.871 +/- 0.007

# %% [markdown]
# ### BaseLine RandomForest with featuretools

# %%
# Time measurement
start_time = time.time()

# Preparation pipeline
prepare_pipeline_base2 = Pipeline([
    ('label-encoder', CountEncoder()),
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('scaler', RobustScaler())
])

X_prep_rf_h1n1 = prepare_pipeline_base2.fit_transform(X, y.iloc[:,0])
X_prep_rf_seasonal = prepare_pipeline_base2.fit_transform(X, y.iloc[:,1])

# Oversampling
oversample_h1n1 = SMOTE(random_state=5)
oversample_seasonal = SMOTE(random_state=5)

X_prep_rf_h1n1, y_h1n1 = oversample_h1n1.fit_resample(X_prep_rf_h1n1, y.iloc[:,0])
X_prep_rf_seasonal, y_seasonal = oversample_seasonal.fit_resample(X_prep_rf_seasonal, y.iloc[:,1])

# Classification pipeline LightGBM
rf_pipeline_base = function_class_pipeline(RandomForestClassifier(n_estimators=300))

# Cross-validated roc auc
scores_h1n1 = function_cross_val_score(rf_pipeline_base, X_prep_rf_h1n1, y_h1n1, skf)
scores_seasonal = function_cross_val_score(rf_pipeline_base, X_prep_rf_seasonal, y_seasonal, skf)

end_time = time.time() - start_time

print('Cross-validated ROC_AUC for h1n1: %0.3f +/- %0.3f' % (scores_h1n1.mean(), scores_h1n1.std()))
print('Cross-validated ROC_AUC for seasonal: %0.3f +/- %0.3f' % (scores_seasonal.mean(), scores_seasonal.std()))

# Add metrics to dataframe
df_metrics = function_add_metrics('rf_pipeline_base', scores_h1n1, scores_seasonal, end_time, X_prep_rf_h1n1)
# Out:
# Cross-validated ROC_AUC for h1n1: 0.957 +/- 0.001
# Cross-validated ROC_AUC for seasonal: 0.852 +/- 0.005

# %% [markdown]
# ## Filter methods

# %%
# Base preparing pipeline
prepare_pipeline = Pipeline([
    ('label-encoder', JamesSteinEncoder()),
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

X_prep_h1n1 = prepare_pipeline.fit_transform(X, y.iloc[:,0])
X_prep_seasonal = prepare_pipeline.fit_transform(X, y.iloc[:,1])

X_test_prep_h1n1 = prepare_pipeline.transform(X_test)
X_test_prep_seasonal = prepare_pipeline.transform(X_test)

# %%
# Oversampling
oversample_h1n1 = SMOTE(random_state=5)
oversample_seasonal = SMOTE(random_state=5)

X_prep_h1n1, y_h1n1 = oversample_h1n1.fit_resample(X_prep_h1n1, y.iloc[:,0])
X_prep_seasonal, y_seasonal = oversample_seasonal.fit_resample(X_prep_seasonal, y.iloc[:,1])

# %% [markdown]
# ### Constant

# %%
# Time measurement
start_time = time.time()

selector_constant_h1n1 = VarianceThreshold(0.0)
selector_constant_seasonal = VarianceThreshold(0.0)

X_selected_constant_h1n1 = selector_constant_h1n1.fit_transform(X_prep_h1n1)
X_selected_constant_seasonal = selector_constant_seasonal.fit_transform(X_prep_seasonal)

print('Base X shape: {}\nSelected X shape: {}'.format(X_prep_h1n1.shape, X_selected_constant_h1n1.shape))

# Classification pipelines
rf_pipeline_constant = function_class_pipeline(RandomForestClassifier(n_estimators=300))
lgbm_pipeline_constant = function_class_pipeline(LGBMClassifier(max_depth=5))

# Cross-validated roc auc
scores_h1n1 = function_cross_val_score(rf_pipeline_constant, X_selected_constant_h1n1, y_h1n1, skf)
scores_seasonal = function_cross_val_score(lgbm_pipeline_constant, X_selected_constant_seasonal, y_seasonal, skf)

end_time = time.time() - start_time

print('Cross-validated ROC_AUC for h1n1: %0.3f +/- %0.3f' % (scores_h1n1.mean(), scores_h1n1.std()))
print('Cross-validated ROC_AUC for seasonal: %0.3f +/- %0.3f' % (scores_seasonal.mean(), scores_seasonal.std()))

# Add metrics to dataframe
df_metrics = function_add_metrics('pipeline_constant', scores_h1n1, scores_seasonal, end_time, X_selected_constant_h1n1)
# Out:
# Base X shape: (42066, 524)
# Selected X shape: (42066, 524)
# Cross-validated ROC_AUC for h1n1: 0.957 +/- 0.002
# Cross-validated ROC_AUC for seasonal: 0.872 +/- 0.007

# %% [markdown]
# ### Quasi-Constant

# %%
# Time measurement
start_time = time.time()

selector_quasi_constant_h1n1 = VarianceThreshold(.85 * (1 - .85))
selector_quasi_constant_seasonal = VarianceThreshold(.85 * (1 - .85))

X_selected_quasi_constant_h1n1 = selector_quasi_constant_h1n1.fit_transform(X_prep_h1n1)
X_selected_quasi_constant_seasonal = selector_quasi_constant_seasonal.fit_transform(X_prep_seasonal)

print('Base X shape: {}\nSelected X shape: {}'.format(X_prep_h1n1.shape, X_selected_quasi_constant_h1n1.shape))

# Classification pipelines
rf_pipeline_quasi_constant = function_class_pipeline(RandomForestClassifier(n_estimators=300))
lgbm_pipeline_quasi_constant = function_class_pipeline(LGBMClassifier(max_depth=5))

# Cross-validated roc auc
scores_h1n1 = function_cross_val_score(rf_pipeline_quasi_constant, X_selected_quasi_constant_h1n1, y_h1n1, skf)
scores_seasonal = function_cross_val_score(lgbm_pipeline_quasi_constant, X_selected_quasi_constant_seasonal, y_seasonal, skf)

end_time = time.time() - start_time

print('Cross-validated ROC_AUC for h1n1: %0.3f +/- %0.3f' % (scores_h1n1.mean(), scores_h1n1.std()))
print('Cross-validated ROC_AUC for seasonal: %0.3f +/- %0.3f' % (scores_seasonal.mean(), scores_seasonal.std()))

# Add metrics to dataframe
df_metrics = function_add_metrics('pipeline_quasi_constant', scores_h1n1, scores_seasonal, end_time, X_selected_quasi_constant_h1n1)
# Out:
# Base X shape: (42066, 524)
# Selected X shape: (42066, 524)
# Cross-validated ROC_AUC for h1n1: 0.957 +/- 0.002
# Cross-validated ROC_AUC for seasonal: 0.872 +/- 0.007

# %% [markdown]
# ### Mutual info

# %%
# Time measurement
start_time = time.time()

selector_mutual_h1n1 = SelectPercentile(mutual_info_classif, percentile=85)
selector_mutual_seasonal = SelectPercentile(mutual_info_classif, percentile=85)

X_selected_mutual_h1n1 = selector_mutual_h1n1.fit_transform(X_prep_h1n1, y_h1n1)
X_selected_mutual_seasonal = selector_mutual_seasonal.fit_transform(X_prep_seasonal, y_seasonal)

print('Base X shape: {}\nSelected X shape: {}'.format(X_prep_h1n1.shape, X_selected_mutual_h1n1.shape))

# Classification pipelines
rf_pipeline_mutual = function_class_pipeline(RandomForestClassifier(n_estimators=300))
lgbm_pipeline_mutual = function_class_pipeline(LGBMClassifier(max_depth=5))

# Cross-validated roc auc
scores_h1n1 = function_cross_val_score(rf_pipeline_mutual, X_selected_mutual_h1n1, y_h1n1, skf)
scores_seasonal = function_cross_val_score(lgbm_pipeline_mutual, X_selected_mutual_seasonal, y_seasonal, skf)

end_time = time.time() - start_time

print('Cross-validated ROC_AUC for h1n1: %0.3f +/- %0.3f' % (scores_h1n1.mean(), scores_h1n1.std()))
print('Cross-validated ROC_AUC for seasonal: %0.3f +/- %0.3f' % (scores_seasonal.mean(), scores_seasonal.std()))

# Add metrics to dataframe
df_metrics = function_add_metrics('pipeline_mutual', scores_h1n1, scores_seasonal, end_time, X_selected_mutual_h1n1)
# Out:
# Base X shape: (42066, 524)
# Selected X shape: (42066, 445)
# Cross-validated ROC_AUC for h1n1: 0.957 +/- 0.002
# Cross-validated ROC_AUC for seasonal: 0.872 +/- 0.007

# %% [markdown]
# ## Wrapper methods

# %%
# Time measurement
start_time = time.time()

selector_wrapper_h1n1 = SequentialFeatureSelector(
                    LGBMClassifier(max_depth=5), 
                    k_features='best', 
                    forward=False, 
                    floating=False,
                    scoring='roc_auc',
                    cv=None,
                    verbose=1,
                    n_jobs=-1)

selector_wrapper_seasonal = SequentialFeatureSelector(
                    LGBMClassifier(max_depth=5), 
                    k_features='best', 
                    forward=False, 
                    floating=False,
                    scoring='roc_auc',
                    cv=None,
                    verbose=1,
                    n_jobs=-1)

X_selected_wrapper_h1n1 = selector_wrapper_h1n1.fit_transform(X_selected_mutual_h1n1[:5000], y_h1n1[:5000])
X_selected_wrapper_seasonal = selector_wrapper_seasonal.fit_transform(X_selected_mutual_h1n1[:5000], y_seasonal[:5000])

print('Base X shape: {}\nSelected X shape: {}'.format(X_prep_h1n1.shape, X_selected_wrapper_h1n1.shape))

# Classification pipelines
rf_pipeline_wrapper = function_class_pipeline(RandomForestClassifier(n_estimators=300))
lgbm_pipeline_wrapper = function_class_pipeline(LGBMClassifier(max_depth=5))

# Cross-validated roc auc
scores_h1n1 = function_cross_val_score(rf_pipeline_wrapper, X_selected_wrapper_h1n1, y_h1n1[:5000], skf)
scores_seasonal = function_cross_val_score(lgbm_pipeline_wrapper, X_selected_wrapper_seasonal, y_seasonal[:5000], skf)

end_time = time.time() - start_time

print('Cross-validated ROC_AUC for h1n1: %0.3f +/- %0.3f' % (scores_h1n1.mean(), scores_h1n1.std()))
print('Cross-validated ROC_AUC for seasonal: %0.3f +/- %0.3f' % (scores_seasonal.mean(), scores_seasonal.std()))

# Add metrics to dataframe
df_metrics = function_add_metrics('pipeline_wrapper', scores_h1n1, scores_seasonal, end_time, X_selected_wrapper_h1n1)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   18.9s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   57.2s
# [Parallel(n_jobs=-1)]: Done 445 out of 445 | elapsed:  2.1min finished
# Features: 444/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.8s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   50.5s
# [Parallel(n_jobs=-1)]: Done 444 out of 444 | elapsed:  2.0min finished
# Features: 443/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.1s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   48.7s
# [Parallel(n_jobs=-1)]: Done 443 out of 443 | elapsed:  2.0min finished
# Features: 442/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   11.2s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   50.6s
# [Parallel(n_jobs=-1)]: Done 442 out of 442 | elapsed:  2.0min finished
# Features: 441/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.6s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   51.9s
# [Parallel(n_jobs=-1)]: Done 441 out of 441 | elapsed:  2.0min finished
# Features: 440/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.4s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   48.5s
# [Parallel(n_jobs=-1)]: Done 440 out of 440 | elapsed:  1.9min finished
# Features: 439/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   47.2s
# [Parallel(n_jobs=-1)]: Done 439 out of 439 | elapsed:  1.9min finished
# Features: 438/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    9.9s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   47.0s
# [Parallel(n_jobs=-1)]: Done 438 out of 438 | elapsed:  1.9min finished
# Features: 437/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   46.9s
# [Parallel(n_jobs=-1)]: Done 437 out of 437 | elapsed:  1.9min finished
# Features: 436/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.4s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   46.8s
# [Parallel(n_jobs=-1)]: Done 436 out of 436 | elapsed:  1.8min finished
# Features: 435/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.6s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   48.7s
# [Parallel(n_jobs=-1)]: Done 435 out of 435 | elapsed:  1.8min finished
# Features: 434/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    9.9s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   47.4s
# [Parallel(n_jobs=-1)]: Done 434 out of 434 | elapsed:  1.8min finished
# Features: 433/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   46.1s
# [Parallel(n_jobs=-1)]: Done 433 out of 433 | elapsed:  1.8min finished
# Features: 432/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.1s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   47.2s
# [Parallel(n_jobs=-1)]: Done 432 out of 432 | elapsed:  1.8min finished
# Features: 431/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   45.7s
# [Parallel(n_jobs=-1)]: Done 431 out of 431 | elapsed:  1.8min finished
# Features: 430/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   46.5s
# [Parallel(n_jobs=-1)]: Done 430 out of 430 | elapsed:  1.8min finished
# Features: 429/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   45.7s
# [Parallel(n_jobs=-1)]: Done 429 out of 429 | elapsed:  1.8min finished
# Features: 428/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    9.7s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   47.1s
# [Parallel(n_jobs=-1)]: Done 428 out of 428 | elapsed:  1.8min finished
# Features: 427/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   47.4s
# [Parallel(n_jobs=-1)]: Done 427 out of 427 | elapsed:  1.9min finished
# Features: 426/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   11.8s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   48.9s
# [Parallel(n_jobs=-1)]: Done 426 out of 426 | elapsed:  1.8min finished
# Features: 425/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   47.3s
# [Parallel(n_jobs=-1)]: Done 425 out of 425 | elapsed:  1.8min finished
# Features: 424/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    9.7s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   46.6s
# [Parallel(n_jobs=-1)]: Done 424 out of 424 | elapsed:  1.8min finished
# Features: 423/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   48.9s
# [Parallel(n_jobs=-1)]: Done 423 out of 423 | elapsed:  1.8min finished
# Features: 422/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    9.5s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   45.9s
# [Parallel(n_jobs=-1)]: Done 422 out of 422 | elapsed:  1.7min finished
# Features: 421/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   45.7s
# [Parallel(n_jobs=-1)]: Done 421 out of 421 | elapsed:  1.7min finished
# Features: 420/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    9.5s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   45.9s
# [Parallel(n_jobs=-1)]: Done 420 out of 420 | elapsed:  1.8min finished
# Features: 419/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.3s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   49.9s
# [Parallel(n_jobs=-1)]: Done 419 out of 419 | elapsed:  1.9min finished
# Features: 418/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   45.4s
# [Parallel(n_jobs=-1)]: Done 418 out of 418 | elapsed:  1.7min finished
# Features: 417/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   48.5s
# [Parallel(n_jobs=-1)]: Done 417 out of 417 | elapsed:  1.8min finished
# Features: 416/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   50.3s
# [Parallel(n_jobs=-1)]: Done 416 out of 416 | elapsed:  1.8min finished
# Features: 415/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   47.1s
# [Parallel(n_jobs=-1)]: Done 415 out of 415 | elapsed:  1.7min finished
# Features: 414/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   44.2s
# [Parallel(n_jobs=-1)]: Done 414 out of 414 | elapsed:  1.6min finished
# Features: 413/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   43.8s
# [Parallel(n_jobs=-1)]: Done 413 out of 413 | elapsed:  1.7min finished
# Features: 412/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   45.7s
# [Parallel(n_jobs=-1)]: Done 412 out of 412 | elapsed:  1.7min finished
# Features: 411/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   51.2s
# [Parallel(n_jobs=-1)]: Done 411 out of 411 | elapsed:  1.9min finished
# Features: 410/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   48.5s
# [Parallel(n_jobs=-1)]: Done 410 out of 410 | elapsed:  1.8min finished
# Features: 409/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   48.2s
# [Parallel(n_jobs=-1)]: Done 409 out of 409 | elapsed:  1.8min finished
# Features: 408/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    9.9s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   47.9s
# [Parallel(n_jobs=-1)]: Done 408 out of 408 | elapsed:  1.7min finished
# Features: 407/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   48.3s
# [Parallel(n_jobs=-1)]: Done 407 out of 407 | elapsed:  1.8min finished
# Features: 406/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.1s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   49.6s
# [Parallel(n_jobs=-1)]: Done 406 out of 406 | elapsed:  1.7min finished
# Features: 405/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   46.8s
# [Parallel(n_jobs=-1)]: Done 405 out of 405 | elapsed:  1.7min finished
# Features: 404/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   47.0s
# [Parallel(n_jobs=-1)]: Done 404 out of 404 | elapsed:  1.7min finished
# Features: 403/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   54.1s
# [Parallel(n_jobs=-1)]: Done 403 out of 403 | elapsed:  1.9min finished
# Features: 402/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   55.5s
# [Parallel(n_jobs=-1)]: Done 402 out of 402 | elapsed:  2.0min finished
# Features: 401/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   11.8s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   54.7s
# [Parallel(n_jobs=-1)]: Done 401 out of 401 | elapsed:  1.9min finished
# Features: 400/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   12.2s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   54.3s
# [Parallel(n_jobs=-1)]: Done 400 out of 400 | elapsed:  1.9min finished
# Features: 399/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   11.2s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   56.7s
# [Parallel(n_jobs=-1)]: Done 399 out of 399 | elapsed:  2.0min finished
# Features: 398/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   11.8s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   55.5s
# [Parallel(n_jobs=-1)]: Done 398 out of 398 | elapsed:  2.0min finished
# Features: 397/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   12.3s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   58.7s
# [Parallel(n_jobs=-1)]: Done 397 out of 397 | elapsed:  2.1min finished
# Features: 396/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   12.5s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   58.9s
# [Parallel(n_jobs=-1)]: Done 396 out of 396 | elapsed:  2.1min finished
# Features: 395/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   12.8s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 395 out of 395 | elapsed:  2.2min finished
# Features: 394/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   12.9s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 394 out of 394 | elapsed:  2.2min finished
# Features: 393/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   12.5s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 393 out of 393 | elapsed:  2.1min finished
# Features: 392/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   12.3s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 392 out of 392 | elapsed:  2.1min finished
# Features: 391/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   13.0s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 391 out of 391 | elapsed:  2.2min finished
# Features: 390/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   12.6s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   59.0s
# [Parallel(n_jobs=-1)]: Done 390 out of 390 | elapsed:  2.0min finished
# Features: 389/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   12.1s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   58.9s
# [Parallel(n_jobs=-1)]: Done 389 out of 389 | elapsed:  2.1min finished
# Features: 388/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   12.7s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 388 out of 388 | elapsed:  2.1min finished
# Features: 387/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   12.1s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   59.0s
# [Parallel(n_jobs=-1)]: Done 387 out of 387 | elapsed:  2.1min finished
# Features: 386/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   12.7s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   59.5s
# [Parallel(n_jobs=-1)]: Done 386 out of 386 | elapsed:  2.1min finished
# Features: 385/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   12.6s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 385 out of 385 | elapsed:  2.0min finished
# Features: 384/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   11.4s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   54.2s
# [Parallel(n_jobs=-1)]: Done 384 out of 384 | elapsed:  1.9min finished
# Features: 383/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   11.4s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   54.6s
# [Parallel(n_jobs=-1)]: Done 383 out of 383 | elapsed:  1.9min finished
# Features: 382/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   12.0s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   58.4s
# [Parallel(n_jobs=-1)]: Done 382 out of 382 | elapsed:  1.9min finished
# Features: 381/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   12.2s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   58.3s
# [Parallel(n_jobs=-1)]: Done 381 out of 381 | elapsed:  1.9min finished
# Features: 380/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   12.2s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   56.6s
# [Parallel(n_jobs=-1)]: Done 380 out of 380 | elapsed:  1.9min finished
# Features: 379/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   12.1s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   56.8s
# [Parallel(n_jobs=-1)]: Done 379 out of 379 | elapsed:  1.9min finished
# Features: 378/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   12.2s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   56.7s
# [Parallel(n_jobs=-1)]: Done 378 out of 378 | elapsed:  1.9min finished
# Features: 377/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   55.1s
# [Parallel(n_jobs=-1)]: Done 377 out of 377 | elapsed:  1.8min finished
# Features: 376/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   11.8s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   54.2s
# [Parallel(n_jobs=-1)]: Done 376 out of 376 | elapsed:  1.8min finished
# Features: 375/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   12.0s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   58.4s
# [Parallel(n_jobs=-1)]: Done 375 out of 375 | elapsed:  2.0min finished
# Features: 374/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   12.7s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 374 out of 374 | elapsed:  2.0min finished
# Features: 373/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   11.7s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   54.0s
# [Parallel(n_jobs=-1)]: Done 373 out of 373 | elapsed:  1.8min finished
# Features: 372/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   54.3s
# [Parallel(n_jobs=-1)]: Done 372 out of 372 | elapsed:  1.8min finished
# Features: 371/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   54.6s
# [Parallel(n_jobs=-1)]: Done 371 out of 371 | elapsed:  1.8min finished
# Features: 370/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.8s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   50.6s
# [Parallel(n_jobs=-1)]: Done 370 out of 370 | elapsed:  1.7min finished
# Features: 369/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.5s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   48.9s
# [Parallel(n_jobs=-1)]: Done 369 out of 369 | elapsed:  1.6min finished
# Features: 368/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.5s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   50.5s
# [Parallel(n_jobs=-1)]: Done 368 out of 368 | elapsed:  1.7min finished
# Features: 367/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.6s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   49.6s
# [Parallel(n_jobs=-1)]: Done 367 out of 367 | elapsed:  1.7min finished
# Features: 366/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.6s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   49.2s
# [Parallel(n_jobs=-1)]: Done 366 out of 366 | elapsed:  1.6min finished
# Features: 365/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.4s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   48.9s
# [Parallel(n_jobs=-1)]: Done 365 out of 365 | elapsed:  1.6min finished
# Features: 364/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.6s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   49.2s
# [Parallel(n_jobs=-1)]: Done 364 out of 364 | elapsed:  1.6min finished
# Features: 363/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.3s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   51.0s
# [Parallel(n_jobs=-1)]: Done 363 out of 363 | elapsed:  1.7min finished
# Features: 362/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   11.3s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   51.2s
# [Parallel(n_jobs=-1)]: Done 362 out of 362 | elapsed:  1.7min finished
# Features: 361/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   55.5s
# [Parallel(n_jobs=-1)]: Done 361 out of 361 | elapsed:  1.8min finished
# Features: 360/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   11.8s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   58.3s
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed:  1.8min finished
# Features: 359/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   12.0s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   57.8s
# [Parallel(n_jobs=-1)]: Done 359 out of 359 | elapsed:  1.8min finished
# Features: 358/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   11.2s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   52.9s
# [Parallel(n_jobs=-1)]: Done 358 out of 358 | elapsed:  1.7min finished
# Features: 357/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   11.8s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   53.2s
# [Parallel(n_jobs=-1)]: Done 357 out of 357 | elapsed:  1.7min finished
# Features: 356/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   11.4s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   54.4s
# [Parallel(n_jobs=-1)]: Done 356 out of 356 | elapsed:  1.7min finished
# Features: 355/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   11.4s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   53.6s
# [Parallel(n_jobs=-1)]: Done 355 out of 355 | elapsed:  1.7min finished
# Features: 354/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   11.8s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   56.0s
# [Parallel(n_jobs=-1)]: Done 354 out of 354 | elapsed:  1.8min finished
# Features: 353/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.8s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   52.6s
# [Parallel(n_jobs=-1)]: Done 353 out of 353 | elapsed:  1.7min finished
# Features: 352/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   54.0s
# [Parallel(n_jobs=-1)]: Done 352 out of 352 | elapsed:  1.7min finished
# Features: 351/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   12.1s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   58.6s
# [Parallel(n_jobs=-1)]: Done 351 out of 351 | elapsed:  1.8min finished
# Features: 350/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   11.0s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   51.9s
# [Parallel(n_jobs=-1)]: Done 350 out of 350 | elapsed:  1.6min finished
# Features: 349/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.7s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   51.2s
# [Parallel(n_jobs=-1)]: Done 349 out of 349 | elapsed:  1.6min finished
# Features: 348/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   51.8s
# [Parallel(n_jobs=-1)]: Done 348 out of 348 | elapsed:  1.6min finished
# Features: 347/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   11.2s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   52.9s
# [Parallel(n_jobs=-1)]: Done 347 out of 347 | elapsed:  1.6min finished
# Features: 346/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   11.0s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   51.8s
# [Parallel(n_jobs=-1)]: Done 346 out of 346 | elapsed:  1.6min finished
# Features: 345/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   51.6s
# [Parallel(n_jobs=-1)]: Done 345 out of 345 | elapsed:  1.6min finished
# Features: 344/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.8s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   51.2s
# [Parallel(n_jobs=-1)]: Done 344 out of 344 | elapsed:  1.6min finished
# Features: 343/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   52.1s
# [Parallel(n_jobs=-1)]: Done 343 out of 343 | elapsed:  1.6min finished
# Features: 342/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   51.9s
# [Parallel(n_jobs=-1)]: Done 342 out of 342 | elapsed:  1.6min finished
# Features: 341/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   50.8s
# [Parallel(n_jobs=-1)]: Done 341 out of 341 | elapsed:  1.6min finished
# Features: 340/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   51.3s
# [Parallel(n_jobs=-1)]: Done 340 out of 340 | elapsed:  1.6min finished
# Features: 339/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   51.1s
# [Parallel(n_jobs=-1)]: Done 339 out of 339 | elapsed:  1.5min finished
# Features: 338/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   51.1s
# [Parallel(n_jobs=-1)]: Done 338 out of 338 | elapsed:  1.5min finished
# Features: 337/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   50.8s
# [Parallel(n_jobs=-1)]: Done 337 out of 337 | elapsed:  1.5min finished
# Features: 336/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   11.2s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   51.8s
# [Parallel(n_jobs=-1)]: Done 336 out of 336 | elapsed:  1.5min finished
# Features: 335/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.8s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   50.6s
# [Parallel(n_jobs=-1)]: Done 335 out of 335 | elapsed:  1.5min finished
# Features: 334/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   11.0s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   51.4s
# [Parallel(n_jobs=-1)]: Done 334 out of 334 | elapsed:  1.5min finished
# Features: 333/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   50.8s
# [Parallel(n_jobs=-1)]: Done 333 out of 333 | elapsed:  1.5min finished
# Features: 332/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.6s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   49.8s
# [Parallel(n_jobs=-1)]: Done 332 out of 332 | elapsed:  1.5min finished
# Features: 331/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.8s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   51.4s
# [Parallel(n_jobs=-1)]: Done 331 out of 331 | elapsed:  1.5min finished
# Features: 330/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   53.9s
# [Parallel(n_jobs=-1)]: Done 330 out of 330 | elapsed:  1.6min finished
# Features: 329/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   11.4s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   51.7s
# [Parallel(n_jobs=-1)]: Done 329 out of 329 | elapsed:  1.5min finished
# Features: 328/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   52.9s
# [Parallel(n_jobs=-1)]: Done 328 out of 328 | elapsed:  1.6min finished
# Features: 327/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.7s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   52.7s
# [Parallel(n_jobs=-1)]: Done 327 out of 327 | elapsed:  1.5min finished
# Features: 326/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   54.9s
# [Parallel(n_jobs=-1)]: Done 326 out of 326 | elapsed:  1.6min finished
# Features: 325/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   54.2s
# [Parallel(n_jobs=-1)]: Done 325 out of 325 | elapsed:  1.5min finished
# Features: 324/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.8s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   52.6s
# [Parallel(n_jobs=-1)]: Done 324 out of 324 | elapsed:  1.5min finished
# Features: 323/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   11.0s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   50.9s
# [Parallel(n_jobs=-1)]: Done 323 out of 323 | elapsed:  1.5min finished
# Features: 322/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   55.7s
# [Parallel(n_jobs=-1)]: Done 322 out of 322 | elapsed:  1.6min finished
# Features: 321/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   52.8s
# [Parallel(n_jobs=-1)]: Done 321 out of 321 | elapsed:  1.5min finished
# Features: 320/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   52.7s
# [Parallel(n_jobs=-1)]: Done 320 out of 320 | elapsed:  1.5min finished
# Features: 319/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   12.3s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   52.9s
# [Parallel(n_jobs=-1)]: Done 319 out of 319 | elapsed:  1.5min finished
# Features: 318/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   54.4s
# [Parallel(n_jobs=-1)]: Done 318 out of 318 | elapsed:  1.5min finished
# Features: 317/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   38.3s
# [Parallel(n_jobs=-1)]: Done 317 out of 317 | elapsed:  1.1min finished
# Features: 316/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   39.7s
# [Parallel(n_jobs=-1)]: Done 316 out of 316 | elapsed:  1.1min finished
# Features: 315/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   35.1s
# [Parallel(n_jobs=-1)]: Done 315 out of 315 | elapsed:   58.6s finished
# Features: 314/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   34.0s
# [Parallel(n_jobs=-1)]: Done 314 out of 314 | elapsed:   58.5s finished
# Features: 313/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   33.6s
# [Parallel(n_jobs=-1)]: Done 313 out of 313 | elapsed:   58.2s finished
# Features: 312/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   38.2s
# [Parallel(n_jobs=-1)]: Done 312 out of 312 | elapsed:  1.1min finished
# Features: 311/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   35.5s
# [Parallel(n_jobs=-1)]: Done 311 out of 311 | elapsed:   59.1s finished
# Features: 310/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   34.8s
# [Parallel(n_jobs=-1)]: Done 310 out of 310 | elapsed:   57.9s finished
# Features: 309/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   35.8s
# [Parallel(n_jobs=-1)]: Done 309 out of 309 | elapsed:   59.2s finished
# Features: 308/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   34.8s
# [Parallel(n_jobs=-1)]: Done 308 out of 308 | elapsed:   56.5s finished
# Features: 307/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   33.2s
# [Parallel(n_jobs=-1)]: Done 307 out of 307 | elapsed:   54.2s finished
# Features: 306/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   35.2s
# [Parallel(n_jobs=-1)]: Done 306 out of 306 | elapsed:   56.8s finished
# Features: 305/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   34.2s
# [Parallel(n_jobs=-1)]: Done 305 out of 305 | elapsed:   55.3s finished
# Features: 304/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   33.6s
# [Parallel(n_jobs=-1)]: Done 304 out of 304 | elapsed:   56.9s finished
# Features: 303/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   35.5s
# [Parallel(n_jobs=-1)]: Done 303 out of 303 | elapsed:   58.8s finished
# Features: 302/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   37.4s
# [Parallel(n_jobs=-1)]: Done 302 out of 302 | elapsed:   58.9s finished
# Features: 301/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   35.5s
# [Parallel(n_jobs=-1)]: Done 301 out of 301 | elapsed:   55.8s finished
# Features: 300/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   34.2s
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:   55.4s finished
# Features: 299/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   33.6s
# [Parallel(n_jobs=-1)]: Done 299 out of 299 | elapsed:   53.7s finished
# Features: 298/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   33.7s
# [Parallel(n_jobs=-1)]: Done 298 out of 298 | elapsed:   53.9s finished
# Features: 297/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   32.9s
# [Parallel(n_jobs=-1)]: Done 297 out of 297 | elapsed:   52.0s finished
# Features: 296/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   33.6s
# [Parallel(n_jobs=-1)]: Done 296 out of 296 | elapsed:   52.9s finished
# Features: 295/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   34.5s
# [Parallel(n_jobs=-1)]: Done 295 out of 295 | elapsed:   53.4s finished
# Features: 294/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   32.9s
# [Parallel(n_jobs=-1)]: Done 294 out of 294 | elapsed:   52.8s finished
# Features: 293/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   32.0s
# [Parallel(n_jobs=-1)]: Done 293 out of 293 | elapsed:   51.9s finished
# Features: 292/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   32.8s
# [Parallel(n_jobs=-1)]: Done 292 out of 292 | elapsed:   51.7s finished
# Features: 291/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   32.4s
# [Parallel(n_jobs=-1)]: Done 291 out of 291 | elapsed:   51.2s finished
# Features: 290/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   33.3s
# [Parallel(n_jobs=-1)]: Done 290 out of 290 | elapsed:   50.8s finished
# Features: 289/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   31.4s
# [Parallel(n_jobs=-1)]: Done 289 out of 289 | elapsed:   49.3s finished
# Features: 288/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   36.3s
# [Parallel(n_jobs=-1)]: Done 288 out of 288 | elapsed:   56.3s finished
# Features: 287/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   30.1s
# [Parallel(n_jobs=-1)]: Done 287 out of 287 | elapsed:   46.7s finished
# Features: 286/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   32.1s
# [Parallel(n_jobs=-1)]: Done 286 out of 286 | elapsed:   48.9s finished
# Features: 285/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   32.1s
# [Parallel(n_jobs=-1)]: Done 285 out of 285 | elapsed:   48.2s finished
# Features: 284/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   31.0s
# [Parallel(n_jobs=-1)]: Done 284 out of 284 | elapsed:   48.6s finished
# Features: 283/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   31.3s
# [Parallel(n_jobs=-1)]: Done 283 out of 283 | elapsed:   47.6s finished
# Features: 282/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   30.9s
# [Parallel(n_jobs=-1)]: Done 282 out of 282 | elapsed:   46.5s finished
# Features: 281/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   31.7s
# [Parallel(n_jobs=-1)]: Done 281 out of 281 | elapsed:   47.3s finished
# Features: 280/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   31.0s
# [Parallel(n_jobs=-1)]: Done 280 out of 280 | elapsed:   46.6s finished
# Features: 279/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   31.0s
# [Parallel(n_jobs=-1)]: Done 279 out of 279 | elapsed:   45.6s finished
# Features: 278/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   31.6s
# ...
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=-1)]: Done  82 out of  82 | elapsed:   14.8s finished
# Features: 81/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=-1)]: Done  81 out of  81 | elapsed:   13.3s finished
# Features: 80/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    6.1s
# [Parallel(n_jobs=-1)]: Done  80 out of  80 | elapsed:   12.9s finished
# Features: 79/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=-1)]: Done  79 out of  79 | elapsed:   13.0s finished
# Features: 78/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=-1)]: Done  78 out of  78 | elapsed:   13.0s finished
# Features: 77/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=-1)]: Done  77 out of  77 | elapsed:   12.3s finished
# Features: 76/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=-1)]: Done  76 out of  76 | elapsed:   12.2s finished
# Features: 75/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=-1)]: Done  75 out of  75 | elapsed:   11.7s finished
# Features: 74/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=-1)]: Done  74 out of  74 | elapsed:   11.8s finished
# Features: 73/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=-1)]: Done  73 out of  73 | elapsed:   11.6s finished
# Features: 72/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=-1)]: Done  72 out of  72 | elapsed:   11.1s finished
# Features: 71/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=-1)]: Done  71 out of  71 | elapsed:   11.2s finished
# Features: 70/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=-1)]: Done  70 out of  70 | elapsed:   11.1s finished
# Features: 69/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=-1)]: Done  69 out of  69 | elapsed:   11.0s finished
# Features: 68/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=-1)]: Done  68 out of  68 | elapsed:   10.3s finished
# Features: 67/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=-1)]: Done  67 out of  67 | elapsed:   10.1s finished
# Features: 66/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=-1)]: Done  66 out of  66 | elapsed:   10.1s finished
# Features: 65/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=-1)]: Done  65 out of  65 | elapsed:    9.6s finished
# Features: 64/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=-1)]: Done  64 out of  64 | elapsed:    9.4s finished
# Features: 63/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=-1)]: Done  63 out of  63 | elapsed:    9.1s finished
# Features: 62/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=-1)]: Done  62 out of  62 | elapsed:    9.1s finished
# Features: 61/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=-1)]: Done  61 out of  61 | elapsed:    8.8s finished
# Features: 60/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    8.8s finished
# Features: 59/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=-1)]: Done  59 out of  59 | elapsed:    9.2s finished
# Features: 58/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=-1)]: Done  58 out of  58 | elapsed:    8.3s finished
# Features: 57/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=-1)]: Done  57 out of  57 | elapsed:    8.2s finished
# Features: 56/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=-1)]: Done  56 out of  56 | elapsed:    8.2s finished
# Features: 55/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=-1)]: Done  55 out of  55 | elapsed:    8.0s finished
# Features: 54/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=-1)]: Done  54 out of  54 | elapsed:    7.5s finished
# Features: 53/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=-1)]: Done  53 out of  53 | elapsed:    7.5s finished
# Features: 52/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=-1)]: Done  52 out of  52 | elapsed:    7.8s finished
# Features: 51/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=-1)]: Done  51 out of  51 | elapsed:    7.5s finished
# Features: 50/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    7.6s finished
# Features: 49/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=-1)]: Done  49 out of  49 | elapsed:    6.8s finished
# Features: 48/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  48 out of  48 | elapsed:    6.8s finished
# Features: 47/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  47 out of  47 | elapsed:    6.7s finished
# Features: 46/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  46 out of  46 | elapsed:    6.1s finished
# Features: 45/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  45 out of  45 | elapsed:    6.2s finished
# Features: 44/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  44 out of  44 | elapsed:    5.7s finished
# Features: 43/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  43 out of  43 | elapsed:    5.7s finished
# Features: 42/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 out of  42 | elapsed:    5.5s finished
# Features: 41/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  41 out of  41 | elapsed:    5.3s finished
# Features: 40/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed:    5.2s finished
# Features: 39/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  39 out of  39 | elapsed:    4.8s finished
# Features: 38/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  38 out of  38 | elapsed:    5.0s finished
# Features: 37/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  37 out of  37 | elapsed:    4.9s finished
# Features: 36/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  36 out of  36 | elapsed:    4.5s finished
# Features: 35/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    4.4s finished
# Features: 34/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 out of  34 | elapsed:    4.3s finished
# Features: 33/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 out of  33 | elapsed:    4.7s finished
# Features: 32/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  32 out of  32 | elapsed:    4.1s finished
# Features: 31/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  31 out of  31 | elapsed:    4.0s finished
# Features: 30/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    3.7s finished
# Features: 29/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    3.5s finished
# Features: 28/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    3.4s finished
# Features: 27/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:    3.3s finished
# Features: 26/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:    3.2s finished
# Features: 25/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:    3.1s finished
# Features: 24/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 out of  24 | elapsed:    2.9s finished
# Features: 23/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  23 | elapsed:    2.7s finished
# Features: 22/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  22 out of  22 | elapsed:    2.7s finished
# Features: 21/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  21 | elapsed:    2.5s finished
# Features: 20/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:    2.3s finished
# Features: 19/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  19 out of  19 | elapsed:    2.2s finished
# Features: 18/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed:    2.2s finished
# Features: 17/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 out of  17 | elapsed:    2.1s finished
# Features: 16/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 out of  16 | elapsed:    2.0s finished
# Features: 15/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:    1.8s finished
# Features: 14/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  14 out of  14 | elapsed:    1.7s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  14 out of  14 | elapsed:    1.7s finished
# Features: 13/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  13 out of  13 | elapsed:    1.6s finished
# Features: 12/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  12 | elapsed:    1.3s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:    1.4s finished
# Features: 11/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 out of  11 | elapsed:    1.2s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  11 out of  11 | elapsed:    1.4s finished
# Features: 10/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of  10 | elapsed:    1.0s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    1.3s finished
# Features: 9/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   9 | elapsed:    0.9s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:    1.2s finished
# Features: 8/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   8 | elapsed:    0.7s remaining:    2.2s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    1.1s finished
# Features: 7/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of   7 | elapsed:    1.0s finished
# Features: 6/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:    0.8s finished
# Features: 5/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    0.5s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.7s finished
# Features: 4/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.6s finished
# Features: 3/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.5s finished
# Features: 2/1[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    0.4s finished
# Features: 1/1
# Base X shape: (42066, 524)
# Selected X shape: (5000, 165)
# Cross-validated ROC_AUC for h1n1: 0.803 +/- 0.009
# Cross-validated ROC_AUC for seasonal: 0.834 +/- 0.010

# %% [markdown]
# ## Emebeded methods

# %% [markdown]
# ### L1-based (LinearSVC)

# %%
# Time measurement
start_time = time.time()

selector_emb_svc_h1n1 = SelectFromModel(LinearSVC(penalty='l1', dual=False))
selector_emb_svc_seasonal = SelectFromModel(LinearSVC(penalty='l1', dual=False))

X_selected_emb_svc_h1n1 = selector_emb_svc_h1n1.fit_transform(X_prep_h1n1, y_h1n1)
X_selected_emb_svc_seasonal = selector_emb_svc_seasonal.fit_transform(X_prep_seasonal, y_seasonal)

print('Base X shape: {}\nSelected X shape: {}'.format(X_prep_h1n1.shape, X_selected_emb_svc_h1n1.shape))

# Classification pipelines
rf_pipeline_emb_svc = function_class_pipeline(RandomForestClassifier(n_estimators=300))
lgbm_pipeline_emb_svc = function_class_pipeline(LGBMClassifier(max_depth=5))

# Cross-validated roc auc
scores_h1n1 = function_cross_val_score(rf_pipeline_emb_svc, X_selected_emb_svc_h1n1, y_h1n1, skf)
scores_seasonal = function_cross_val_score(lgbm_pipeline_emb_svc, X_selected_emb_svc_seasonal, y_seasonal, skf)

end_time = time.time() - start_time

print('Cross-validated ROC_AUC for h1n1: %0.3f +/- %0.3f' % (scores_h1n1.mean(), scores_h1n1.std()))
print('Cross-validated ROC_AUC for seasonal: %0.3f +/- %0.3f' % (scores_seasonal.mean(), scores_seasonal.std()))

# Add metrics to dataframe
df_metrics = function_add_metrics('pipeline_emb_svc', scores_h1n1, scores_seasonal, end_time, X_selected_emb_svc_h1n1)
# Out:
# Base X shape: (42066, 524)
# Selected X shape: (42066, 456)
# Cross-validated ROC_AUC for h1n1: 0.957 +/- 0.002
# Cross-validated ROC_AUC for seasonal: 0.872 +/- 0.007

# %% [markdown]
# ### L1-based (LogisticRegression)

# %%
# Time measurement
start_time = time.time()

selector_emb_log_h1n1 = SelectFromModel(LogisticRegression(penalty='l1',solver='liblinear'))
selector_emb_log_seasonal = SelectFromModel(LogisticRegression(penalty='l1',solver='liblinear'))

X_selected_emb_log_h1n1 = selector_emb_log_h1n1.fit_transform(X_prep_h1n1, y_h1n1)
X_selected_emb_log_seasonal = selector_emb_log_seasonal.fit_transform(X_prep_seasonal, y_seasonal)

print('Base X shape: {}\nSelected X shape: {}'.format(X_prep_h1n1.shape, X_selected_emb_log_h1n1.shape))

# Classification pipelines
rf_pipeline_emb_log = function_class_pipeline(RandomForestClassifier(n_estimators=300))
lgbm_pipeline_emb_log = function_class_pipeline(LGBMClassifier(max_depth=5))

# Cross-validated roc auc
scores_h1n1 = function_cross_val_score(rf_pipeline_emb_log, X_selected_emb_log_h1n1, y_h1n1, skf)
scores_seasonal = function_cross_val_score(lgbm_pipeline_emb_log, X_selected_emb_log_seasonal, y_seasonal, skf)

end_time = time.time() - start_time

print('Cross-validated ROC_AUC for h1n1: %0.3f +/- %0.3f' % (scores_h1n1.mean(), scores_h1n1.std()))
print('Cross-validated ROC_AUC for seasonal: %0.3f +/- %0.3f' % (scores_seasonal.mean(), scores_seasonal.std()))

# Add metrics to dataframe
df_metrics = function_add_metrics('pipeline_emb_log', scores_h1n1, scores_seasonal, end_time, X_selected_emb_log_h1n1)
# Out:
# Base X shape: (42066, 524)
# Selected X shape: (42066, 401)
# Cross-validated ROC_AUC for h1n1: 0.956 +/- 0.002
# Cross-validated ROC_AUC for seasonal: 0.872 +/- 0.007

# %% [markdown]
# ### ExtraTreesClassifier

# %%
# Time measurement
start_time = time.time()

selector_emb_trees_h1n1 = SelectFromModel(ExtraTreesClassifier(n_estimators=200))
selector_emb_trees_seasonal = SelectFromModel(ExtraTreesClassifier(n_estimators=200))

X_selected_emb_trees_h1n1 = selector_emb_trees_h1n1.fit_transform(X_prep_h1n1, y_h1n1)
X_selected_emb_trees_seasonal = selector_emb_trees_seasonal.fit_transform(X_prep_seasonal, y_seasonal)

print('Base X shape: {}\nSelected X shape: {}'.format(X_prep_h1n1.shape, X_selected_emb_trees_h1n1.shape))

# Classification pipelines
rf_pipeline_emb_trees = function_class_pipeline(RandomForestClassifier(n_estimators=300))
lgbm_pipeline_emb_trees = function_class_pipeline(LGBMClassifier(max_depth=5))

# Cross-validated roc auc
scores_h1n1 = function_cross_val_score(rf_pipeline_emb_trees, X_selected_emb_trees_h1n1, y_h1n1, skf)
scores_seasonal = function_cross_val_score(lgbm_pipeline_emb_trees, X_selected_emb_trees_seasonal, y_seasonal, skf)

end_time = time.time() - start_time

print('Cross-validated ROC_AUC for h1n1: %0.3f +/- %0.3f' % (scores_h1n1.mean(), scores_h1n1.std()))
print('Cross-validated ROC_AUC for seasonal: %0.3f +/- %0.3f' % (scores_seasonal.mean(), scores_seasonal.std()))

# Add metrics to dataframe
df_metrics = function_add_metrics('pipeline_emb_trees', scores_h1n1, scores_seasonal, end_time, X_selected_emb_trees_h1n1)
# Out:
# Base X shape: (42066, 524)
# Selected X shape: (42066, 182)
# Cross-validated ROC_AUC for h1n1: 0.953 +/- 0.002
# Cross-validated ROC_AUC for seasonal: 0.869 +/- 0.007

# %% [markdown]
# ## RFECV

# %%
# Time measurement
start_time = time.time()

selector_rfecv_h1n1 = RFECV(estimator=LinearSVC(penalty='l1', dual=False), step=2, cv=None, scoring='roc_auc', verbose=1,  min_features_to_select=350)
selector_rfecv_seasonal = RFECV(estimator=LinearSVC(penalty='l1', dual=False), step=2, cv=None, scoring='roc_auc', verbose=1,  min_features_to_select=350)

X_selected_rfecv_h1n1 = selector_rfecv_h1n1.fit_transform(X_selected_mutual_h1n1[:5000], y_h1n1[:5000])
X_selected_rfecv_seasonal = selector_rfecv_seasonal.fit_transform(X_selected_mutual_seasonal[:5000], y_seasonal[:5000])

print('Base X shape: {}\nSelected X shape: {}'.format(X_prep_h1n1.shape, X_selected_rfecv_h1n1.shape))

# Classification pipelines
rf_pipeline_rfecv = function_class_pipeline(RandomForestClassifier(n_estimators=300))
lgbm_pipeline_rfecv = function_class_pipeline(LGBMClassifier(max_depth=5))

# Cross-validated roc auc
scores_h1n1 = function_cross_val_score(rf_pipeline_rfecv, X_selected_rfecv_h1n1, y_h1n1[:5000], skf)
scores_seasonal = function_cross_val_score(lgbm_pipeline_rfecv, X_selected_rfecv_seasonal, y_seasonal[:5000], skf)

end_time = time.time() - start_time

print('Cross-validated ROC_AUC for h1n1: %0.3f +/- %0.3f' % (scores_h1n1.mean(), scores_h1n1.std()))
print('Cross-validated ROC_AUC for seasonal: %0.3f +/- %0.3f' % (scores_seasonal.mean(), scores_seasonal.std()))

# Add metrics to dataframe
df_metrics = function_add_metrics('pipeline_rfecv', scores_h1n1, scores_seasonal, end_time, X_selected_rfecv_h1n1)
# Out:
# Fitting estimator with 445 features.
# Fitting estimator with 443 features.
# Fitting estimator with 441 features.
# Fitting estimator with 439 features.
# Fitting estimator with 437 features.
# Fitting estimator with 435 features.
# Fitting estimator with 433 features.
# Fitting estimator with 431 features.
# Fitting estimator with 429 features.
# Fitting estimator with 427 features.
# Fitting estimator with 425 features.
# Fitting estimator with 423 features.
# Fitting estimator with 421 features.
# Fitting estimator with 419 features.
# Fitting estimator with 417 features.
# Fitting estimator with 415 features.
# Fitting estimator with 413 features.
# Fitting estimator with 411 features.
# Fitting estimator with 409 features.
# Fitting estimator with 407 features.
# Fitting estimator with 405 features.
# Fitting estimator with 403 features.
# Fitting estimator with 401 features.
# Fitting estimator with 399 features.
# Fitting estimator with 397 features.
# Fitting estimator with 395 features.
# Fitting estimator with 393 features.
# Fitting estimator with 391 features.
# Fitting estimator with 389 features.
# Fitting estimator with 387 features.
# Fitting estimator with 385 features.
# Fitting estimator with 383 features.
# Fitting estimator with 381 features.
# Fitting estimator with 379 features.
# Fitting estimator with 377 features.
# Fitting estimator with 375 features.
# Fitting estimator with 373 features.
# Fitting estimator with 371 features.
# Fitting estimator with 369 features.
# Fitting estimator with 367 features.
# Fitting estimator with 365 features.
# Fitting estimator with 363 features.
# Fitting estimator with 361 features.
# Fitting estimator with 359 features.
# Fitting estimator with 357 features.
# Fitting estimator with 355 features.
# Fitting estimator with 353 features.
# Fitting estimator with 351 features.
# Fitting estimator with 445 features.
# Fitting estimator with 443 features.
# Fitting estimator with 441 features.
# Fitting estimator with 439 features.
# Fitting estimator with 437 features.
# Fitting estimator with 435 features.
# Fitting estimator with 433 features.
# Fitting estimator with 431 features.
# Fitting estimator with 429 features.
# Fitting estimator with 427 features.
# Fitting estimator with 425 features.
# Fitting estimator with 423 features.
# Fitting estimator with 421 features.
# Fitting estimator with 419 features.
# Fitting estimator with 417 features.
# Fitting estimator with 415 features.
# Fitting estimator with 413 features.
# Fitting estimator with 411 features.
# Fitting estimator with 409 features.
# Fitting estimator with 407 features.
# Fitting estimator with 405 features.
# Fitting estimator with 403 features.
# Fitting estimator with 401 features.
# Fitting estimator with 399 features.
# Fitting estimator with 397 features.
# Fitting estimator with 395 features.
# Fitting estimator with 393 features.
# Fitting estimator with 391 features.
# Fitting estimator with 389 features.
# Fitting estimator with 387 features.
# Fitting estimator with 385 features.
# Fitting estimator with 383 features.
# Fitting estimator with 381 features.
# Fitting estimator with 379 features.
# Fitting estimator with 377 features.
# Fitting estimator with 375 features.
# Fitting estimator with 373 features.
# Fitting estimator with 371 features.
# Fitting estimator with 369 features.
# Fitting estimator with 367 features.
# Fitting estimator with 365 features.
# Fitting estimator with 363 features.
# Fitting estimator with 361 features.
# Fitting estimator with 359 features.
# Fitting estimator with 357 features.
# Fitting estimator with 355 features.
# Fitting estimator with 353 features.
# Fitting estimator with 351 features.
# Fitting estimator with 445 features.
# Fitting estimator with 443 features.
# Fitting estimator with 441 features.
# Fitting estimator with 439 features.
# Fitting estimator with 437 features.
# Fitting estimator with 435 features.
# Fitting estimator with 433 features.
# Fitting estimator with 431 features.
# Fitting estimator with 429 features.
# Fitting estimator with 427 features.
# Fitting estimator with 425 features.
# Fitting estimator with 423 features.
# Fitting estimator with 421 features.
# Fitting estimator with 419 features.
# Fitting estimator with 417 features.
# Fitting estimator with 415 features.
# Fitting estimator with 413 features.
# Fitting estimator with 411 features.
# Fitting estimator with 409 features.
# Fitting estimator with 407 features.
# Fitting estimator with 405 features.
# Fitting estimator with 403 features.
# Fitting estimator with 401 features.
# Fitting estimator with 399 features.
# Fitting estimator with 397 features.
# Fitting estimator with 395 features.
# Fitting estimator with 393 features.
# Fitting estimator with 391 features.
# Fitting estimator with 389 features.
# Fitting estimator with 387 features.
# Fitting estimator with 385 features.
# Fitting estimator with 383 features.
# Fitting estimator with 381 features.
# Fitting estimator with 379 features.
# Fitting estimator with 377 features.
# Fitting estimator with 375 features.
# Fitting estimator with 373 features.
# Fitting estimator with 371 features.
# Fitting estimator with 369 features.
# Fitting estimator with 367 features.
# Fitting estimator with 365 features.
# Fitting estimator with 363 features.
# Fitting estimator with 361 features.
# Fitting estimator with 359 features.
# Fitting estimator with 357 features.
# Fitting estimator with 355 features.
# Fitting estimator with 353 features.
# Fitting estimator with 351 features.
# Fitting estimator with 445 features.
# Fitting estimator with 443 features.
# Fitting estimator with 441 features.
# Fitting estimator with 439 features.
# Fitting estimator with 437 features.
# Fitting estimator with 435 features.
# Fitting estimator with 433 features.
# Fitting estimator with 431 features.
# Fitting estimator with 429 features.
# Fitting estimator with 427 features.
# Fitting estimator with 425 features.
# Fitting estimator with 423 features.
# Fitting estimator with 421 features.
# Fitting estimator with 419 features.
# Fitting estimator with 417 features.
# Fitting estimator with 415 features.
# Fitting estimator with 413 features.
# Fitting estimator with 411 features.
# Fitting estimator with 409 features.
# Fitting estimator with 407 features.
# Fitting estimator with 405 features.
# Fitting estimator with 403 features.
# Fitting estimator with 401 features.
# Fitting estimator with 399 features.
# Fitting estimator with 397 features.
# Fitting estimator with 395 features.
# Fitting estimator with 393 features.
# Fitting estimator with 391 features.
# Fitting estimator with 389 features.
# Fitting estimator with 387 features.
# Fitting estimator with 385 features.
# Fitting estimator with 383 features.
# Fitting estimator with 381 features.
# Fitting estimator with 379 features.
# Fitting estimator with 377 features.
# Fitting estimator with 375 features.
# Fitting estimator with 373 features.
# Fitting estimator with 371 features.
# Fitting estimator with 369 features.
# Fitting estimator with 367 features.
# Fitting estimator with 365 features.
# Fitting estimator with 363 features.
# Fitting estimator with 361 features.
# Fitting estimator with 359 features.
# Fitting estimator with 357 features.
# Fitting estimator with 355 features.
# Fitting estimator with 353 features.
# Fitting estimator with 351 features.
# Fitting estimator with 445 features.
# Fitting estimator with 443 features.
# Fitting estimator with 441 features.
# Fitting estimator with 439 features.
# Fitting estimator with 437 features.
# Fitting estimator with 435 features.
# Fitting estimator with 433 features.
# Fitting estimator with 431 features.
# Fitting estimator with 429 features.
# Fitting estimator with 427 features.
# Fitting estimator with 425 features.
# Fitting estimator with 423 features.
# Fitting estimator with 421 features.
# Fitting estimator with 419 features.
# Fitting estimator with 417 features.
# Fitting estimator with 415 features.
# Fitting estimator with 413 features.
# Fitting estimator with 411 features.
# Fitting estimator with 409 features.
# Fitting estimator with 407 features.
# Fitting estimator with 405 features.
# Fitting estimator with 403 features.
# Fitting estimator with 401 features.
# Fitting estimator with 399 features.
# Fitting estimator with 397 features.
# Fitting estimator with 395 features.
# Fitting estimator with 393 features.
# Fitting estimator with 391 features.
# Fitting estimator with 389 features.
# Fitting estimator with 387 features.
# Fitting estimator with 385 features.
# Fitting estimator with 383 features.
# Fitting estimator with 381 features.
# Fitting estimator with 379 features.
# Fitting estimator with 377 features.
# Fitting estimator with 375 features.
# Fitting estimator with 373 features.
# Fitting estimator with 371 features.
# Fitting estimator with 369 features.
# Fitting estimator with 367 features.
# Fitting estimator with 365 features.
# Fitting estimator with 363 features.
# Fitting estimator with 361 features.
# Fitting estimator with 359 features.
# Fitting estimator with 357 features.
# Fitting estimator with 355 features.
# Fitting estimator with 353 features.
# Fitting estimator with 351 features.
# Fitting estimator with 445 features.
# Fitting estimator with 443 features.
# Fitting estimator with 441 features.
# Fitting estimator with 439 features.
# Fitting estimator with 437 features.
# Fitting estimator with 435 features.
# Fitting estimator with 433 features.
# Fitting estimator with 431 features.
# Fitting estimator with 429 features.
# Fitting estimator with 427 features.
# Fitting estimator with 425 features.
# Fitting estimator with 423 features.
# Fitting estimator with 421 features.
# Fitting estimator with 419 features.
# Fitting estimator with 417 features.
# Fitting estimator with 415 features.
# Fitting estimator with 413 features.
# Fitting estimator with 411 features.
# Fitting estimator with 409 features.
# Fitting estimator with 407 features.
# Fitting estimator with 405 features.
# Fitting estimator with 403 features.
# Fitting estimator with 401 features.
# Fitting estimator with 399 features.
# Fitting estimator with 397 features.
# Fitting estimator with 395 features.
# Fitting estimator with 393 features.
# Fitting estimator with 391 features.
# Fitting estimator with 389 features.
# Fitting estimator with 387 features.
# Fitting estimator with 385 features.
# Fitting estimator with 383 features.
# Fitting estimator with 381 features.
# Fitting estimator with 379 features.
# Fitting estimator with 377 features.
# Fitting estimator with 375 features.
# Fitting estimator with 373 features.
# Fitting estimator with 371 features.
# Fitting estimator with 369 features.
# Fitting estimator with 367 features.
# Fitting estimator with 365 features.
# Fitting estimator with 363 features.
# Fitting estimator with 361 features.
# Fitting estimator with 359 features.
# Fitting estimator with 357 features.
# Fitting estimator with 355 features.
# Fitting estimator with 445 features.
# Fitting estimator with 443 features.
# Fitting estimator with 441 features.
# Fitting estimator with 439 features.
# Fitting estimator with 437 features.
# Fitting estimator with 435 features.
# Fitting estimator with 433 features.
# Fitting estimator with 431 features.
# Fitting estimator with 429 features.
# Fitting estimator with 427 features.
# Fitting estimator with 425 features.
# Fitting estimator with 423 features.
# Fitting estimator with 421 features.
# Fitting estimator with 419 features.
# Fitting estimator with 417 features.
# Fitting estimator with 415 features.
# Fitting estimator with 413 features.
# Fitting estimator with 411 features.
# Fitting estimator with 409 features.
# Fitting estimator with 407 features.
# Fitting estimator with 405 features.
# Fitting estimator with 403 features.
# Fitting estimator with 401 features.
# Fitting estimator with 399 features.
# Fitting estimator with 397 features.
# Fitting estimator with 395 features.
# Fitting estimator with 393 features.
# Fitting estimator with 391 features.
# Fitting estimator with 389 features.
# Fitting estimator with 387 features.
# Fitting estimator with 385 features.
# Fitting estimator with 383 features.
# Fitting estimator with 381 features.
# Fitting estimator with 379 features.
# Fitting estimator with 377 features.
# Fitting estimator with 375 features.
# Fitting estimator with 373 features.
# Fitting estimator with 371 features.
# Fitting estimator with 369 features.
# Fitting estimator with 367 features.
# Fitting estimator with 365 features.
# Fitting estimator with 363 features.
# Fitting estimator with 361 features.
# Fitting estimator with 359 features.
# Fitting estimator with 357 features.
# Fitting estimator with 355 features.
# Fitting estimator with 353 features.
# Fitting estimator with 351 features.
# Fitting estimator with 445 features.
# Fitting estimator with 443 features.
# Fitting estimator with 441 features.
# Fitting estimator with 439 features.
# Fitting estimator with 437 features.
# Fitting estimator with 435 features.
# Fitting estimator with 433 features.
# Fitting estimator with 431 features.
# Fitting estimator with 429 features.
# Fitting estimator with 427 features.
# Fitting estimator with 425 features.
# Fitting estimator with 423 features.
# Fitting estimator with 421 features.
# Fitting estimator with 419 features.
# Fitting estimator with 417 features.
# Fitting estimator with 415 features.
# Fitting estimator with 413 features.
# Fitting estimator with 411 features.
# Fitting estimator with 409 features.
# Fitting estimator with 407 features.
# Fitting estimator with 405 features.
# Fitting estimator with 403 features.
# Fitting estimator with 401 features.
# Fitting estimator with 399 features.
# Fitting estimator with 397 features.
# Fitting estimator with 395 features.
# Fitting estimator with 393 features.
# Fitting estimator with 391 features.
# Fitting estimator with 389 features.
# Fitting estimator with 387 features.
# Fitting estimator with 385 features.
# Fitting estimator with 383 features.
# Fitting estimator with 381 features.
# Fitting estimator with 379 features.
# Fitting estimator with 377 features.
# Fitting estimator with 375 features.
# Fitting estimator with 373 features.
# Fitting estimator with 371 features.
# Fitting estimator with 369 features.
# Fitting estimator with 367 features.
# Fitting estimator with 365 features.
# Fitting estimator with 363 features.
# Fitting estimator with 361 features.
# Fitting estimator with 359 features.
# Fitting estimator with 357 features.
# Fitting estimator with 355 features.
# Fitting estimator with 353 features.
# Fitting estimator with 351 features.
# Fitting estimator with 445 features.
# Fitting estimator with 443 features.
# Fitting estimator with 441 features.
# Fitting estimator with 439 features.
# Fitting estimator with 437 features.
# Fitting estimator with 435 features.
# Fitting estimator with 433 features.
# Fitting estimator with 431 features.
# Fitting estimator with 429 features.
# Fitting estimator with 427 features.
# Fitting estimator with 425 features.
# Fitting estimator with 423 features.
# Fitting estimator with 421 features.
# Fitting estimator with 419 features.
# Fitting estimator with 417 features.
# Fitting estimator with 415 features.
# Fitting estimator with 413 features.
# Fitting estimator with 411 features.
# Fitting estimator with 409 features.
# Fitting estimator with 407 features.
# Fitting estimator with 405 features.
# Fitting estimator with 403 features.
# Fitting estimator with 401 features.
# Fitting estimator with 399 features.
# Fitting estimator with 397 features.
# Fitting estimator with 395 features.
# Fitting estimator with 393 features.
# Fitting estimator with 391 features.
# Fitting estimator with 389 features.
# Fitting estimator with 387 features.
# Fitting estimator with 385 features.
# Fitting estimator with 383 features.
# Fitting estimator with 381 features.
# Fitting estimator with 379 features.
# Fitting estimator with 377 features.
# Fitting estimator with 375 features.
# Fitting estimator with 373 features.
# Fitting estimator with 371 features.
# Fitting estimator with 369 features.
# Fitting estimator with 367 features.
# Fitting estimator with 365 features.
# Fitting estimator with 363 features.
# Fitting estimator with 361 features.
# Fitting estimator with 359 features.
# Fitting estimator with 357 features.
# Fitting estimator with 355 features.
# Fitting estimator with 353 features.
# Fitting estimator with 351 features.
# Fitting estimator with 445 features.
# Fitting estimator with 443 features.
# Fitting estimator with 441 features.
# Fitting estimator with 439 features.
# Fitting estimator with 437 features.
# Fitting estimator with 435 features.
# Fitting estimator with 433 features.
# Fitting estimator with 431 features.
# Fitting estimator with 429 features.
# Fitting estimator with 427 features.
# Fitting estimator with 425 features.
# Fitting estimator with 423 features.
# Fitting estimator with 421 features.
# Fitting estimator with 419 features.
# Fitting estimator with 417 features.
# Fitting estimator with 415 features.
# Fitting estimator with 413 features.
# Fitting estimator with 411 features.
# Fitting estimator with 409 features.
# Fitting estimator with 407 features.
# Fitting estimator with 405 features.
# Fitting estimator with 403 features.
# Fitting estimator with 401 features.
# Fitting estimator with 399 features.
# Fitting estimator with 397 features.
# Fitting estimator with 395 features.
# Fitting estimator with 393 features.
# Fitting estimator with 391 features.
# Fitting estimator with 389 features.
# Fitting estimator with 387 features.
# Fitting estimator with 385 features.
# Fitting estimator with 383 features.
# Fitting estimator with 381 features.
# Fitting estimator with 379 features.
# Fitting estimator with 377 features.
# Fitting estimator with 375 features.
# Fitting estimator with 373 features.
# Fitting estimator with 371 features.
# Fitting estimator with 369 features.
# Fitting estimator with 367 features.
# Fitting estimator with 365 features.
# Fitting estimator with 363 features.
# Fitting estimator with 361 features.
# Fitting estimator with 359 features.
# Fitting estimator with 357 features.
# Fitting estimator with 355 features.
# Fitting estimator with 353 features.
# Fitting estimator with 351 features.
# Fitting estimator with 445 features.
# Fitting estimator with 443 features.
# Fitting estimator with 441 features.
# Fitting estimator with 439 features.
# Fitting estimator with 437 features.
# Fitting estimator with 435 features.
# Fitting estimator with 433 features.
# Fitting estimator with 431 features.
# Fitting estimator with 429 features.
# Fitting estimator with 427 features.
# Fitting estimator with 425 features.
# Fitting estimator with 423 features.
# Fitting estimator with 421 features.
# Fitting estimator with 419 features.
# Fitting estimator with 417 features.
# Fitting estimator with 415 features.
# Fitting estimator with 413 features.
# Fitting estimator with 411 features.
# Fitting estimator with 409 features.
# Fitting estimator with 407 features.
# Fitting estimator with 405 features.
# Fitting estimator with 403 features.
# Fitting estimator with 401 features.
# Fitting estimator with 399 features.
# Fitting estimator with 397 features.
# Fitting estimator with 395 features.
# Fitting estimator with 393 features.
# Fitting estimator with 391 features.
# Fitting estimator with 389 features.
# Fitting estimator with 387 features.
# Fitting estimator with 385 features.
# Fitting estimator with 383 features.
# Fitting estimator with 381 features.
# Fitting estimator with 379 features.
# Fitting estimator with 377 features.
# Fitting estimator with 375 features.
# Fitting estimator with 373 features.
# Fitting estimator with 371 features.
# Fitting estimator with 369 features.
# Fitting estimator with 367 features.
# Fitting estimator with 365 features.
# Fitting estimator with 363 features.
# Fitting estimator with 361 features.
# Fitting estimator with 359 features.
# Fitting estimator with 357 features.
# Fitting estimator with 355 features.
# Fitting estimator with 353 features.
# Fitting estimator with 351 features.
# Fitting estimator with 445 features.
# Fitting estimator with 443 features.
# Fitting estimator with 441 features.
# Fitting estimator with 439 features.
# Fitting estimator with 437 features.
# Fitting estimator with 435 features.
# Fitting estimator with 433 features.
# Fitting estimator with 431 features.
# Fitting estimator with 429 features.
# Fitting estimator with 427 features.
# Fitting estimator with 425 features.
# Fitting estimator with 423 features.
# Fitting estimator with 421 features.
# Fitting estimator with 419 features.
# Fitting estimator with 417 features.
# Fitting estimator with 415 features.
# Fitting estimator with 413 features.
# Fitting estimator with 411 features.
# Fitting estimator with 409 features.
# Fitting estimator with 407 features.
# Fitting estimator with 405 features.
# Fitting estimator with 403 features.
# Fitting estimator with 401 features.
# Fitting estimator with 399 features.
# Fitting estimator with 397 features.
# Fitting estimator with 395 features.
# Fitting estimator with 393 features.
# Fitting estimator with 391 features.
# Fitting estimator with 389 features.
# Fitting estimator with 387 features.
# Fitting estimator with 385 features.
# Fitting estimator with 383 features.
# Fitting estimator with 381 features.
# Fitting estimator with 379 features.
# Fitting estimator with 377 features.
# Fitting estimator with 375 features.
# Fitting estimator with 373 features.
# Fitting estimator with 371 features.
# Fitting estimator with 369 features.
# Fitting estimator with 367 features.
# Fitting estimator with 365 features.
# Fitting estimator with 363 features.
# Fitting estimator with 361 features.
# Fitting estimator with 359 features.
# Fitting estimator with 357 features.
# Fitting estimator with 355 features.
# Fitting estimator with 353 features.
# Base X shape: (42066, 524)
# Selected X shape: (5000, 353)
# Cross-validated ROC_AUC for h1n1: 0.800 +/- 0.008
# Cross-validated ROC_AUC for seasonal: 0.834 +/- 0.009

# %% [markdown]
# ## Permutation Importance

# %%
from eli5.sklearn import PermutationImportance
roc_scorer = make_scorer(roc_auc_score, needs_proba=True)

# Time measurement
start_time = time.time()

selector_perm_h1n1 = SelectFromModel(PermutationImportance(LogisticRegression(penalty="l1", solver='liblinear'), scoring=roc_scorer, cv=None), threshold=0.00001)
selector_perm_seasonal = SelectFromModel(PermutationImportance(LogisticRegression(penalty="l1", solver='liblinear'), scoring=roc_scorer, cv=None), threshold=0.00001)

X_selected_perm_h1n1 = selector_perm_h1n1.fit_transform(X_prep_h1n1, y_h1n1)
X_selected_perm_seasonal = selector_perm_seasonal.fit_transform(X_prep_seasonal, y_seasonal)

print('Base X shape: {}\nSelected X shape: {}'.format(X_prep_h1n1.shape, X_selected_perm_h1n1.shape))

# Classification pipelines
rf_pipeline_perm = function_class_pipeline(RandomForestClassifier(n_estimators=300))
lgbm_pipeline_perm = function_class_pipeline(LGBMClassifier(max_depth=5))

# Cross-validated roc auc
scores_h1n1 = function_cross_val_score(rf_pipeline_perm, X_selected_perm_h1n1, y_h1n1, skf)
scores_seasonal = function_cross_val_score(lgbm_pipeline_perm, X_selected_perm_seasonal, y_seasonal, skf)

end_time = time.time() - start_time

print('Cross-validated ROC_AUC for h1n1: %0.3f +/- %0.3f' % (scores_h1n1.mean(), scores_h1n1.std()))
print('Cross-validated ROC_AUC for seasonal: %0.3f +/- %0.3f' % (scores_seasonal.mean(), scores_seasonal.std()))

# Add metrics to dataframe
df_metrics = function_add_metrics('pipeline_perm', scores_h1n1, scores_seasonal, end_time, X_selected_perm_h1n1)
# Out:
# Base X shape: (42066, 524)
# Selected X shape: (42066, 365)
# Cross-validated ROC_AUC for h1n1: 0.956 +/- 0.002
# Cross-validated ROC_AUC for seasonal: 0.872 +/- 0.007

# %% [markdown]
# ## FeatureGradientSelector

# %%
# Time measurement
start_time = time.time()

selector_fgs_h1n1 = FeatureGradientSelector(n_features=400)
selector_fgs_seasonal = FeatureGradientSelector(n_features=400)

X_selected_fgs_h1n1 = selector_fgs_h1n1.fit_transform(X_prep_h1n1, y_h1n1)
X_selected_fgs_seasonal = selector_fgs_seasonal.fit_transform(X_prep_seasonal, y_seasonal)

print('Base X shape: {}\nSelected X shape: {}'.format(X_prep_h1n1.shape, X_selected_fgs_h1n1.shape))

# Classification pipeline LightGBM
rf_pipeline_fgs = function_class_pipeline(RandomForestClassifier(n_estimators=300))
lgbm_pipeline_fgs = function_class_pipeline(LGBMClassifier(max_depth=5))

# Cross-validated roc auc
scores_h1n1 = function_cross_val_score(rf_pipeline_fgs, X_selected_fgs_h1n1, y_h1n1, skf)
scores_seasonal = function_cross_val_score(lgbm_pipeline_fgs, X_selected_fgs_seasonal, y_seasonal, skf)

end_time = time.time() - start_time

print('Cross-validated ROC_AUC for h1n1: %0.3f +/- %0.3f' % (scores_h1n1.mean(), scores_h1n1.std()))
print('Cross-validated ROC_AUC for seasonal: %0.3f +/- %0.3f' % (scores_seasonal.mean(), scores_seasonal.std()))

# Add metrics to dataframe
df_metrics = function_add_metrics('pipeline_fgs', scores_h1n1, scores_seasonal, end_time, X_selected_fgs_h1n1)
# Out:
# Base X shape: (42066, 524)
# Selected X shape: (42066, 400)
# Cross-validated ROC_AUC for h1n1: 0.954 +/- 0.001
# Cross-validated ROC_AUC for seasonal: 0.871 +/- 0.006

# %% [markdown]
# ## GBDTSelector

# %%
# Time measurement
start_time = time.time()

selector_gbdt_h1n1 = GBDTSelector()
selector_gbdt_seasonal = GBDTSelector()

selector_gbdt_h1n1.fit(X_prep_h1n1, y_h1n1, 
                          lgb_params={'boosting_type':'gbdt','metric':'AUC','verbosity':0},
                          eval_ratio=0.25,
                          early_stopping_rounds=5,
                          importance_type='gain',
                          num_boost_round=50)

selector_gbdt_seasonal.fit(X_prep_seasonal, y_seasonal, 
                          lgb_params={'boosting_type':'gbdt','metric':'AUC','verbosity':0},
                          eval_ratio=0.25,
                          early_stopping_rounds=5,
                          importance_type='gain',
                          num_boost_round=50)

X_selected_gbdt_h1n1 = X_prep_h1n1[:, selector_gbdt_h1n1.get_selected_features(500)]
X_selected_gbdt_seasonal = X_prep_seasonal[:, selector_gbdt_seasonal.get_selected_features(500)]

print('Base X shape: {}\nSelected X shape: {}'.format(X_prep_h1n1.shape, X_selected_gbdt_h1n1.shape))

# Classification pipeline LightGBM
rf_pipeline_gbdt = function_class_pipeline(RandomForestClassifier(n_estimators=300))
lgbm_pipeline_gbdt = function_class_pipeline(LGBMClassifier(max_depth=5))

# Cross-validated roc auc
scores_h1n1 = function_cross_val_score(rf_pipeline_gbdt, X_selected_gbdt_h1n1, y_h1n1, skf)
scores_seasonal = function_cross_val_score(lgbm_pipeline_gbdt, X_selected_gbdt_seasonal, y_seasonal, skf)

end_time = time.time() - start_time

print('Cross-validated ROC_AUC for h1n1: %0.3f +/- %0.3f' % (scores_h1n1.mean(), scores_h1n1.std()))
print('Cross-validated ROC_AUC for seasonal: %0.3f +/- %0.3f' % (scores_seasonal.mean(), scores_seasonal.std()))

# Add metrics to dataframe
df_metrics = function_add_metrics('pipeline_gbdt', scores_h1n1, scores_seasonal, end_time, X_selected_gbdt_h1n1)
# Out:
# C:\Users\koren\AppData\Roaming\Python\Python39\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.164275 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [1]	valid_0's auc: 0.892702
# Training until validation scores don't improve for 5 rounds
# [2]	valid_0's auc: 0.906475
# [3]	valid_0's auc: 0.910557
# [4]	valid_0's auc: 0.916212
# [5]	valid_0's auc: 0.920163
# [6]	valid_0's auc: 0.922393
# [7]	valid_0's auc: 0.925565
# [8]	valid_0's auc: 0.926776
# [9]	valid_0's auc: 0.93027
# [10]	valid_0's auc: 0.932598
# [11]	valid_0's auc: 0.934268
# [12]	valid_0's auc: 0.936215
# [13]	valid_0's auc: 0.937345
# [14]	valid_0's auc: 0.938701
# [15]	valid_0's auc: 0.940148
# [16]	valid_0's auc: 0.940935
# [17]	valid_0's auc: 0.941742
# [18]	valid_0's auc: 0.942455
# [19]	valid_0's auc: 0.943679
# [20]	valid_0's auc: 0.944197
# [21]	valid_0's auc: 0.944995
# [22]	valid_0's auc: 0.945631
# [23]	valid_0's auc: 0.946089
# [24]	valid_0's auc: 0.946613
# [25]	valid_0's auc: 0.946931
# [26]	valid_0's auc: 0.947341
# [27]	valid_0's auc: 0.947649
# [28]	valid_0's auc: 0.94804
# [29]	valid_0's auc: 0.948491
# [30]	valid_0's auc: 0.948897
# [31]	valid_0's auc: 0.949262
# [32]	valid_0's auc: 0.94954
# [33]	valid_0's auc: 0.949809
# [34]	valid_0's auc: 0.950127
# [35]	valid_0's auc: 0.950468
# [36]	valid_0's auc: 0.950553
# [37]	valid_0's auc: 0.950729
# [38]	valid_0's auc: 0.950908
# [39]	valid_0's auc: 0.951076
# [40]	valid_0's auc: 0.951241
# [41]	valid_0's auc: 0.951433
# [42]	valid_0's auc: 0.951532
# [43]	valid_0's auc: 0.951651
# [44]	valid_0's auc: 0.951759
# [45]	valid_0's auc: 0.951869
# [46]	valid_0's auc: 0.952001
# [47]	valid_0's auc: 0.952165
# [48]	valid_0's auc: 0.952207
# [49]	valid_0's auc: 0.952166
# [50]	valid_0's auc: 0.952251
# Did not meet early stopping. Best iteration is:
# [50]	valid_0's auc: 0.952251
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.080176 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [1]	valid_0's auc: 0.831379
# Training until validation scores don't improve for 5 rounds
# [2]	valid_0's auc: 0.838212
# [3]	valid_0's auc: 0.841761
# [4]	valid_0's auc: 0.845762
# [5]	valid_0's auc: 0.84802
# [6]	valid_0's auc: 0.849378
# [7]	valid_0's auc: 0.851621
# [8]	valid_0's auc: 0.852679
# [9]	valid_0's auc: 0.85426
# [10]	valid_0's auc: 0.855013
# [11]	valid_0's auc: 0.856037
# [12]	valid_0's auc: 0.857689
# [13]	valid_0's auc: 0.859273
# [14]	valid_0's auc: 0.860212
# [15]	valid_0's auc: 0.861153
# [16]	valid_0's auc: 0.861612
# [17]	valid_0's auc: 0.862455
# [18]	valid_0's auc: 0.863405
# [19]	valid_0's auc: 0.864116
# [20]	valid_0's auc: 0.864625
# [21]	valid_0's auc: 0.864934
# [22]	valid_0's auc: 0.865486
# [23]	valid_0's auc: 0.866049
# [24]	valid_0's auc: 0.866773
# [25]	valid_0's auc: 0.867289
# [26]	valid_0's auc: 0.867583
# [27]	valid_0's auc: 0.868091
# [28]	valid_0's auc: 0.868439
# [29]	valid_0's auc: 0.868616
# [30]	valid_0's auc: 0.868941
# [31]	valid_0's auc: 0.869599
# [32]	valid_0's auc: 0.869956
# [33]	valid_0's auc: 0.87008
# [34]	valid_0's auc: 0.870639
# [35]	valid_0's auc: 0.870802
# [36]	valid_0's auc: 0.870726
# [37]	valid_0's auc: 0.871127
# [38]	valid_0's auc: 0.87126
# [39]	valid_0's auc: 0.871687
# [40]	valid_0's auc: 0.871846
# [41]	valid_0's auc: 0.871911
# [42]	valid_0's auc: 0.872106
# [43]	valid_0's auc: 0.872166
# [44]	valid_0's auc: 0.872249
# [45]	valid_0's auc: 0.872368
# [46]	valid_0's auc: 0.872499
# [47]	valid_0's auc: 0.872477
# [48]	valid_0's auc: 0.872622
# [49]	valid_0's auc: 0.872548
# [50]	valid_0's auc: 0.872688
# Did not meet early stopping. Best iteration is:
# [50]	valid_0's auc: 0.872688
# Base X shape: (42066, 524)
# Selected X shape: (42066, 500)
# Cross-validated ROC_AUC for h1n1: 0.957 +/- 0.002
# Cross-validated ROC_AUC for seasonal: 0.872 +/- 0.007

# %% [markdown]
# ## Results

# %%
# examples of important features
columns_features = selector_mutual_h1n1.get_support(indices=True)
df_important_features = X.iloc[:, columns_features]

[i for i in features_df_new.columns.tolist()]
# Out:
# ['h1n1_concern',
#  'h1n1_knowledge',
#  'behavioral_avoidance',
#  'behavioral_wash_hands',
#  'behavioral_large_gatherings',
#  'behavioral_outside_home',
#  'behavioral_touch_face',
#  'doctor_recc_h1n1',
#  'doctor_recc_seasonal',
#  'chronic_med_condition',
#  'health_worker',
#  'opinion_h1n1_vacc_effective',
#  'opinion_h1n1_risk',
#  'opinion_h1n1_sick_from_vacc',
#  'opinion_seas_vacc_effective',
#  'opinion_seas_risk',
#  'opinion_seas_sick_from_vacc',
#  'age_group',
#  'education',
#  'race',
#  'sex',
#  'income_poverty',
#  'marital_status',
#  'rent_or_own',
#  'employment_status',
#  'hhs_geo_region',
#  'census_msa',
#  'household_adults',
#  'household_children',
#  'employment_industry',
#  'employment_occupation',
#  'h1n1_concern + h1n1_knowledge',
#  'h1n1_concern + household_adults',
#  'h1n1_concern + household_children',
#  'h1n1_concern + opinion_h1n1_risk',
#  'h1n1_concern + opinion_h1n1_sick_from_vacc',
#  'h1n1_concern + opinion_h1n1_vacc_effective',
#  'h1n1_concern + opinion_seas_risk',
#  'h1n1_concern + opinion_seas_sick_from_vacc',
#  'h1n1_concern + opinion_seas_vacc_effective',
#  'h1n1_knowledge + household_adults',
#  'h1n1_knowledge + household_children',
#  'h1n1_knowledge + opinion_h1n1_risk',
#  'h1n1_knowledge + opinion_h1n1_sick_from_vacc',
#  'h1n1_knowledge + opinion_h1n1_vacc_effective',
#  'h1n1_knowledge + opinion_seas_risk',
#  'h1n1_knowledge + opinion_seas_sick_from_vacc',
#  'h1n1_knowledge + opinion_seas_vacc_effective',
#  'household_adults + household_children',
#  'household_adults + opinion_h1n1_risk',
#  'household_adults + opinion_h1n1_sick_from_vacc',
#  'household_adults + opinion_h1n1_vacc_effective',
#  'household_adults + opinion_seas_risk',
#  'household_adults + opinion_seas_sick_from_vacc',
#  'household_adults + opinion_seas_vacc_effective',
#  'household_children + opinion_h1n1_risk',
#  'household_children + opinion_h1n1_sick_from_vacc',
#  'household_children + opinion_h1n1_vacc_effective',
#  'household_children + opinion_seas_risk',
#  'household_children + opinion_seas_sick_from_vacc',
#  'household_children + opinion_seas_vacc_effective',
#  'opinion_h1n1_risk + opinion_h1n1_sick_from_vacc',
#  'opinion_h1n1_risk + opinion_h1n1_vacc_effective',
#  'opinion_h1n1_risk + opinion_seas_risk',
#  'opinion_h1n1_risk + opinion_seas_sick_from_vacc',
#  'opinion_h1n1_risk + opinion_seas_vacc_effective',
#  'opinion_h1n1_sick_from_vacc + opinion_h1n1_vacc_effective',
#  'opinion_h1n1_sick_from_vacc + opinion_seas_risk',
#  'opinion_h1n1_sick_from_vacc + opinion_seas_sick_from_vacc',
#  'opinion_h1n1_sick_from_vacc + opinion_seas_vacc_effective',
#  'opinion_h1n1_vacc_effective + opinion_seas_risk',
#  'opinion_h1n1_vacc_effective + opinion_seas_sick_from_vacc',
#  'opinion_h1n1_vacc_effective + opinion_seas_vacc_effective',
#  'opinion_seas_risk + opinion_seas_sick_from_vacc',
#  'opinion_seas_risk + opinion_seas_vacc_effective',
#  'opinion_seas_sick_from_vacc + opinion_seas_vacc_effective',
#  'AND(behavioral_antiviral_meds, chronic_med_condition)',
#  'AND(behavioral_avoidance, behavioral_large_gatherings)',
#  'AND(behavioral_avoidance, behavioral_outside_home)',
#  'AND(behavioral_avoidance, behavioral_touch_face)',
#  'AND(behavioral_avoidance, behavioral_wash_hands)',
#  'AND(behavioral_avoidance, child_under_6_months)',
#  'AND(behavioral_avoidance, chronic_med_condition)',
#  'AND(behavioral_avoidance, doctor_recc_h1n1)',
#  'AND(behavioral_avoidance, doctor_recc_seasonal)',
#  'AND(behavioral_avoidance, health_insurance)',
#  'AND(behavioral_avoidance, health_worker)',
#  'AND(behavioral_face_mask, behavioral_large_gatherings)',
#  'AND(behavioral_face_mask, behavioral_touch_face)',
#  'AND(behavioral_face_mask, doctor_recc_h1n1)',
#  'AND(behavioral_large_gatherings, behavioral_outside_home)',
#  'AND(behavioral_large_gatherings, behavioral_touch_face)',
#  'AND(behavioral_large_gatherings, behavioral_wash_hands)',
#  'AND(behavioral_large_gatherings, chronic_med_condition)',
#  'AND(behavioral_large_gatherings, doctor_recc_h1n1)',
#  'AND(behavioral_large_gatherings, doctor_recc_seasonal)',
#  'AND(behavioral_large_gatherings, health_insurance)',
#  'AND(behavioral_large_gatherings, health_worker)',
#  'AND(behavioral_outside_home, behavioral_touch_face)',
#  'AND(behavioral_outside_home, behavioral_wash_hands)',
#  'AND(behavioral_outside_home, child_under_6_months)',
#  'AND(behavioral_outside_home, chronic_med_condition)',
#  'AND(behavioral_outside_home, doctor_recc_h1n1)',
#  'AND(behavioral_outside_home, doctor_recc_seasonal)',
#  'AND(behavioral_outside_home, health_insurance)',
#  'AND(behavioral_outside_home, health_worker)',
#  'AND(behavioral_touch_face, behavioral_wash_hands)',
#  'AND(behavioral_touch_face, child_under_6_months)',
#  'AND(behavioral_touch_face, chronic_med_condition)',
#  'AND(behavioral_touch_face, doctor_recc_h1n1)',
#  'AND(behavioral_touch_face, doctor_recc_seasonal)',
#  'AND(behavioral_touch_face, health_insurance)',
#  'AND(behavioral_touch_face, health_worker)',
#  'AND(behavioral_wash_hands, chronic_med_condition)',
#  'AND(behavioral_wash_hands, doctor_recc_h1n1)',
#  'AND(behavioral_wash_hands, doctor_recc_seasonal)',
#  'AND(behavioral_wash_hands, health_insurance)',
#  'AND(behavioral_wash_hands, health_worker)',
#  'AND(child_under_6_months, doctor_recc_h1n1)',
#  'AND(child_under_6_months, doctor_recc_seasonal)',
#  'AND(chronic_med_condition, doctor_recc_h1n1)',
#  'AND(chronic_med_condition, doctor_recc_seasonal)',
#  'AND(chronic_med_condition, health_insurance)',
#  'AND(chronic_med_condition, health_worker)',
#  'AND(doctor_recc_h1n1, doctor_recc_seasonal)',
#  'AND(doctor_recc_h1n1, health_insurance)',
#  'AND(doctor_recc_h1n1, health_worker)',
#  'AND(doctor_recc_seasonal, health_insurance)',
#  'AND(doctor_recc_seasonal, health_worker)',
#  'AND(health_insurance, health_worker)',
#  'DIFF(h1n1_concern)',
#  'DIFF(h1n1_knowledge)',
#  'DIFF(household_adults)',
#  'DIFF(household_children)',
#  'DIFF(opinion_h1n1_risk)',
#  'DIFF(opinion_h1n1_sick_from_vacc)',
#  'DIFF(opinion_h1n1_vacc_effective)',
#  'DIFF(opinion_seas_risk)',
#  'DIFF(opinion_seas_sick_from_vacc)',
#  'DIFF(opinion_seas_vacc_effective)',
#  'behavioral_avoidance * behavioral_large_gatherings',
#  'behavioral_avoidance * behavioral_outside_home',
#  'behavioral_avoidance * behavioral_touch_face',
#  'behavioral_avoidance * behavioral_wash_hands',
#  'behavioral_avoidance * child_under_6_months',
#  'behavioral_avoidance * chronic_med_condition',
#  'behavioral_avoidance * doctor_recc_h1n1',
#  'behavioral_avoidance * doctor_recc_seasonal',
#  'behavioral_avoidance * health_insurance',
#  'behavioral_avoidance * health_worker',
#  'behavioral_face_mask * behavioral_large_gatherings',
#  'behavioral_face_mask * behavioral_outside_home',
#  'behavioral_face_mask * behavioral_touch_face',
#  'behavioral_face_mask * doctor_recc_h1n1',
#  'behavioral_face_mask * health_insurance',
#  'behavioral_large_gatherings * behavioral_outside_home',
#  'behavioral_large_gatherings * behavioral_touch_face',
#  'behavioral_large_gatherings * behavioral_wash_hands',
#  'behavioral_large_gatherings * child_under_6_months',
#  'behavioral_large_gatherings * chronic_med_condition',
#  'behavioral_large_gatherings * doctor_recc_h1n1',
#  'behavioral_large_gatherings * doctor_recc_seasonal',
#  'behavioral_large_gatherings * health_insurance',
#  'behavioral_large_gatherings * health_worker',
#  'behavioral_outside_home * behavioral_touch_face',
#  'behavioral_outside_home * behavioral_wash_hands',
#  'behavioral_outside_home * chronic_med_condition',
#  'behavioral_outside_home * doctor_recc_h1n1',
#  'behavioral_outside_home * doctor_recc_seasonal',
#  'behavioral_outside_home * health_insurance',
#  'behavioral_touch_face * behavioral_wash_hands',
#  'behavioral_touch_face * child_under_6_months',
#  'behavioral_touch_face * chronic_med_condition',
#  'behavioral_touch_face * doctor_recc_h1n1',
#  'behavioral_touch_face * doctor_recc_seasonal',
#  'behavioral_touch_face * health_insurance',
#  'behavioral_touch_face * health_worker',
#  'behavioral_wash_hands * chronic_med_condition',
#  'behavioral_wash_hands * doctor_recc_h1n1',
#  'behavioral_wash_hands * doctor_recc_seasonal',
#  'behavioral_wash_hands * health_insurance',
#  'behavioral_wash_hands * health_worker',
#  'chronic_med_condition * doctor_recc_h1n1',
#  'chronic_med_condition * doctor_recc_seasonal',
#  'chronic_med_condition * health_insurance',
#  'chronic_med_condition * health_worker',
#  'doctor_recc_h1n1 * doctor_recc_seasonal',
#  'doctor_recc_h1n1 * health_insurance',
#  'doctor_recc_h1n1 * health_worker',
#  'doctor_recc_seasonal * health_insurance',
#  'doctor_recc_seasonal * health_worker',
#  'health_insurance * health_worker',
#  'h1n1_concern * h1n1_knowledge',
#  'h1n1_concern * household_adults',
#  'h1n1_concern * household_children',
#  'h1n1_concern * opinion_h1n1_risk',
#  'h1n1_concern * opinion_h1n1_sick_from_vacc',
#  'h1n1_concern * opinion_h1n1_vacc_effective',
#  'h1n1_concern * opinion_seas_risk',
#  'h1n1_concern * opinion_seas_sick_from_vacc',
#  'h1n1_concern * opinion_seas_vacc_effective',
#  'h1n1_knowledge * household_adults',
#  'h1n1_knowledge * household_children',
#  'h1n1_knowledge * opinion_h1n1_risk',
#  'h1n1_knowledge * opinion_h1n1_sick_from_vacc',
#  'h1n1_knowledge * opinion_h1n1_vacc_effective',
#  'h1n1_knowledge * opinion_seas_risk',
#  'h1n1_knowledge * opinion_seas_sick_from_vacc',
#  'h1n1_knowledge * opinion_seas_vacc_effective',
#  'household_adults * household_children',
#  'household_adults * opinion_h1n1_risk',
#  'household_adults * opinion_h1n1_sick_from_vacc',
#  'household_adults * opinion_h1n1_vacc_effective',
#  'household_adults * opinion_seas_risk',
#  'household_adults * opinion_seas_sick_from_vacc',
#  'household_adults * opinion_seas_vacc_effective',
#  'household_children * opinion_h1n1_risk',
#  'household_children * opinion_h1n1_sick_from_vacc',
#  'household_children * opinion_h1n1_vacc_effective',
#  'household_children * opinion_seas_risk',
#  'household_children * opinion_seas_sick_from_vacc',
#  'household_children * opinion_seas_vacc_effective',
#  'opinion_h1n1_risk * opinion_h1n1_sick_from_vacc',
#  'opinion_h1n1_risk * opinion_h1n1_vacc_effective',
#  'opinion_h1n1_risk * opinion_seas_risk',
#  'opinion_h1n1_risk * opinion_seas_sick_from_vacc',
#  'opinion_h1n1_risk * opinion_seas_vacc_effective',
#  'opinion_h1n1_sick_from_vacc * opinion_h1n1_vacc_effective',
#  'opinion_h1n1_sick_from_vacc * opinion_seas_risk',
#  'opinion_h1n1_sick_from_vacc * opinion_seas_sick_from_vacc',
#  'opinion_h1n1_sick_from_vacc * opinion_seas_vacc_effective',
#  'opinion_h1n1_vacc_effective * opinion_seas_risk',
#  'opinion_h1n1_vacc_effective * opinion_seas_sick_from_vacc',
#  'opinion_h1n1_vacc_effective * opinion_seas_vacc_effective',
#  'opinion_seas_risk * opinion_seas_sick_from_vacc',
#  'opinion_seas_risk * opinion_seas_vacc_effective',
#  'opinion_seas_sick_from_vacc * opinion_seas_vacc_effective',
#  'behavioral_antiviral_meds * h1n1_concern',
#  'behavioral_antiviral_meds * household_children',
#  'behavioral_antiviral_meds * opinion_h1n1_risk',
#  'behavioral_antiviral_meds * opinion_h1n1_sick_from_vacc',
#  'behavioral_antiviral_meds * opinion_h1n1_vacc_effective',
#  'behavioral_antiviral_meds * opinion_seas_risk',
#  'behavioral_antiviral_meds * opinion_seas_sick_from_vacc',
#  'behavioral_antiviral_meds * opinion_seas_vacc_effective',
#  'behavioral_avoidance * h1n1_concern',
#  'behavioral_avoidance * h1n1_knowledge',
#  'behavioral_avoidance * household_adults',
#  'behavioral_avoidance * household_children',
#  'behavioral_avoidance * opinion_h1n1_risk',
#  'behavioral_avoidance * opinion_h1n1_sick_from_vacc',
#  'behavioral_avoidance * opinion_h1n1_vacc_effective',
#  'behavioral_avoidance * opinion_seas_risk',
#  'behavioral_avoidance * opinion_seas_sick_from_vacc',
#  'behavioral_avoidance * opinion_seas_vacc_effective',
#  'behavioral_face_mask * h1n1_concern',
#  'behavioral_face_mask * h1n1_knowledge',
#  'behavioral_face_mask * household_adults',
#  'behavioral_face_mask * household_children',
#  'behavioral_face_mask * opinion_h1n1_risk',
#  'behavioral_face_mask * opinion_h1n1_sick_from_vacc',
#  'behavioral_face_mask * opinion_h1n1_vacc_effective',
#  'behavioral_face_mask * opinion_seas_risk',
#  'behavioral_face_mask * opinion_seas_sick_from_vacc',
#  'behavioral_face_mask * opinion_seas_vacc_effective',
#  'behavioral_large_gatherings * h1n1_concern',
#  'behavioral_large_gatherings * h1n1_knowledge',
#  'behavioral_large_gatherings * household_adults',
#  'behavioral_large_gatherings * household_children',
#  'behavioral_large_gatherings * opinion_h1n1_risk',
#  'behavioral_large_gatherings * opinion_h1n1_sick_from_vacc',
#  'behavioral_large_gatherings * opinion_h1n1_vacc_effective',
#  'behavioral_large_gatherings * opinion_seas_risk',
#  'behavioral_large_gatherings * opinion_seas_sick_from_vacc',
#  'behavioral_large_gatherings * opinion_seas_vacc_effective',
#  'behavioral_outside_home * h1n1_concern',
#  'behavioral_outside_home * h1n1_knowledge',
#  'behavioral_outside_home * household_adults',
#  'behavioral_outside_home * household_children',
#  'behavioral_outside_home * opinion_h1n1_risk',
#  'behavioral_outside_home * opinion_h1n1_sick_from_vacc',
#  'behavioral_outside_home * opinion_h1n1_vacc_effective',
#  'behavioral_outside_home * opinion_seas_risk',
#  'behavioral_outside_home * opinion_seas_sick_from_vacc',
#  'behavioral_outside_home * opinion_seas_vacc_effective',
#  'behavioral_touch_face * h1n1_concern',
#  'behavioral_touch_face * h1n1_knowledge',
#  'behavioral_touch_face * household_adults',
#  'behavioral_touch_face * household_children',
#  'behavioral_touch_face * opinion_h1n1_risk',
#  'behavioral_touch_face * opinion_h1n1_sick_from_vacc',
#  'behavioral_touch_face * opinion_h1n1_vacc_effective',
#  'behavioral_touch_face * opinion_seas_risk',
#  'behavioral_touch_face * opinion_seas_sick_from_vacc',
#  'behavioral_touch_face * opinion_seas_vacc_effective',
#  'behavioral_wash_hands * h1n1_concern',
#  'behavioral_wash_hands * h1n1_knowledge',
#  'behavioral_wash_hands * household_adults',
#  'behavioral_wash_hands * household_children',
#  'behavioral_wash_hands * opinion_h1n1_risk',
#  'behavioral_wash_hands * opinion_h1n1_sick_from_vacc',
#  'behavioral_wash_hands * opinion_h1n1_vacc_effective',
#  'behavioral_wash_hands * opinion_seas_risk',
#  'behavioral_wash_hands * opinion_seas_sick_from_vacc',
#  'behavioral_wash_hands * opinion_seas_vacc_effective',
#  'child_under_6_months * h1n1_concern',
#  'child_under_6_months * h1n1_knowledge',
#  'child_under_6_months * household_adults',
#  'child_under_6_months * household_children',
#  'child_under_6_months * opinion_h1n1_risk',
#  'child_under_6_months * opinion_h1n1_sick_from_vacc',
#  'child_under_6_months * opinion_h1n1_vacc_effective',
#  'child_under_6_months * opinion_seas_risk',
#  'child_under_6_months * opinion_seas_sick_from_vacc',
#  'child_under_6_months * opinion_seas_vacc_effective',
#  'chronic_med_condition * h1n1_concern',
#  'chronic_med_condition * h1n1_knowledge',
#  'chronic_med_condition * household_adults',
#  'chronic_med_condition * household_children',
#  'chronic_med_condition * opinion_h1n1_risk',
#  'chronic_med_condition * opinion_h1n1_sick_from_vacc',
#  'chronic_med_condition * opinion_h1n1_vacc_effective',
#  'chronic_med_condition * opinion_seas_risk',
#  'chronic_med_condition * opinion_seas_sick_from_vacc',
#  'chronic_med_condition * opinion_seas_vacc_effective',
#  'doctor_recc_h1n1 * h1n1_concern',
#  'doctor_recc_h1n1 * h1n1_knowledge',
#  'doctor_recc_h1n1 * household_adults',
#  'doctor_recc_h1n1 * household_children',
#  'doctor_recc_h1n1 * opinion_h1n1_risk',
#  'doctor_recc_h1n1 * opinion_h1n1_sick_from_vacc',
#  'doctor_recc_h1n1 * opinion_h1n1_vacc_effective',
#  'doctor_recc_h1n1 * opinion_seas_risk',
#  'doctor_recc_h1n1 * opinion_seas_sick_from_vacc',
#  'doctor_recc_h1n1 * opinion_seas_vacc_effective',
#  'doctor_recc_seasonal * h1n1_concern',
#  'doctor_recc_seasonal * h1n1_knowledge',
#  'doctor_recc_seasonal * household_adults',
#  'doctor_recc_seasonal * household_children',
#  'doctor_recc_seasonal * opinion_h1n1_risk',
#  'doctor_recc_seasonal * opinion_h1n1_sick_from_vacc',
#  'doctor_recc_seasonal * opinion_h1n1_vacc_effective',
#  'doctor_recc_seasonal * opinion_seas_risk',
#  'doctor_recc_seasonal * opinion_seas_sick_from_vacc',
#  'doctor_recc_seasonal * opinion_seas_vacc_effective',
#  'h1n1_concern * health_insurance',
#  'h1n1_concern * health_worker',
#  'h1n1_knowledge * health_insurance',
#  'h1n1_knowledge * health_worker',
#  'health_insurance * household_adults',
#  'health_insurance * household_children',
#  'health_insurance * opinion_h1n1_risk',
#  'health_insurance * opinion_h1n1_sick_from_vacc',
#  'health_insurance * opinion_h1n1_vacc_effective',
#  'health_insurance * opinion_seas_risk',
#  'health_insurance * opinion_seas_sick_from_vacc',
#  'health_insurance * opinion_seas_vacc_effective',
#  'health_worker * household_adults',
#  'health_worker * household_children',
#  'health_worker * opinion_h1n1_risk',
#  'health_worker * opinion_h1n1_sick_from_vacc',
#  'health_worker * opinion_h1n1_vacc_effective',
#  'health_worker * opinion_seas_risk',
#  'health_worker * opinion_seas_sick_from_vacc',
#  'health_worker * opinion_seas_vacc_effective',
#  'OR(behavioral_antiviral_meds, behavioral_avoidance)',
#  'OR(behavioral_antiviral_meds, behavioral_large_gatherings)',
#  'OR(behavioral_antiviral_meds, behavioral_outside_home)',
#  'OR(behavioral_antiviral_meds, behavioral_touch_face)',
#  'OR(behavioral_antiviral_meds, behavioral_wash_hands)',
#  'OR(behavioral_antiviral_meds, child_under_6_months)',
#  'OR(behavioral_antiviral_meds, chronic_med_condition)',
#  'OR(behavioral_antiviral_meds, doctor_recc_h1n1)',
#  'OR(behavioral_antiviral_meds, doctor_recc_seasonal)',
#  'OR(behavioral_antiviral_meds, health_insurance)',
#  'OR(behavioral_antiviral_meds, health_worker)',
#  'OR(behavioral_avoidance, behavioral_face_mask)',
#  'OR(behavioral_avoidance, behavioral_large_gatherings)',
#  'OR(behavioral_avoidance, behavioral_outside_home)',
#  'OR(behavioral_avoidance, behavioral_touch_face)',
#  'OR(behavioral_avoidance, behavioral_wash_hands)',
#  'OR(behavioral_avoidance, child_under_6_months)',
#  'OR(behavioral_avoidance, chronic_med_condition)',
#  'OR(behavioral_avoidance, doctor_recc_h1n1)',
#  'OR(behavioral_avoidance, doctor_recc_seasonal)',
#  'OR(behavioral_avoidance, health_worker)',
#  'OR(behavioral_face_mask, behavioral_large_gatherings)',
#  'OR(behavioral_face_mask, behavioral_touch_face)',
#  'OR(behavioral_face_mask, behavioral_wash_hands)',
#  'OR(behavioral_face_mask, chronic_med_condition)',
#  'OR(behavioral_face_mask, doctor_recc_h1n1)',
#  'OR(behavioral_face_mask, doctor_recc_seasonal)',
#  'OR(behavioral_face_mask, health_worker)',
#  'OR(behavioral_large_gatherings, behavioral_outside_home)',
#  'OR(behavioral_large_gatherings, behavioral_touch_face)',
#  'OR(behavioral_large_gatherings, behavioral_wash_hands)',
#  'OR(behavioral_large_gatherings, child_under_6_months)',
#  'OR(behavioral_large_gatherings, chronic_med_condition)',
#  'OR(behavioral_large_gatherings, doctor_recc_h1n1)',
#  'OR(behavioral_large_gatherings, doctor_recc_seasonal)',
#  'OR(behavioral_large_gatherings, health_insurance)',
#  'OR(behavioral_large_gatherings, health_worker)',
#  'OR(behavioral_outside_home, behavioral_touch_face)',
#  'OR(behavioral_outside_home, behavioral_wash_hands)',
#  'OR(behavioral_outside_home, child_under_6_months)',
#  'OR(behavioral_outside_home, chronic_med_condition)',
#  'OR(behavioral_outside_home, doctor_recc_h1n1)',
#  'OR(behavioral_outside_home, doctor_recc_seasonal)',
#  'OR(behavioral_outside_home, health_worker)',
#  'OR(behavioral_touch_face, behavioral_wash_hands)',
#  'OR(behavioral_touch_face, child_under_6_months)',
#  'OR(behavioral_touch_face, chronic_med_condition)',
#  'OR(behavioral_touch_face, doctor_recc_h1n1)',
#  'OR(behavioral_touch_face, doctor_recc_seasonal)',
#  'OR(behavioral_touch_face, health_worker)',
#  'OR(behavioral_wash_hands, child_under_6_months)',
#  'OR(behavioral_wash_hands, chronic_med_condition)',
#  'OR(behavioral_wash_hands, doctor_recc_h1n1)',
#  'OR(behavioral_wash_hands, doctor_recc_seasonal)',
#  'OR(behavioral_wash_hands, health_worker)',
#  'OR(child_under_6_months, chronic_med_condition)',
#  'OR(child_under_6_months, doctor_recc_h1n1)',
#  'OR(child_under_6_months, doctor_recc_seasonal)',
#  'OR(child_under_6_months, health_insurance)',
#  'OR(child_under_6_months, health_worker)',
#  'OR(chronic_med_condition, doctor_recc_h1n1)',
#  'OR(chronic_med_condition, doctor_recc_seasonal)',
#  'OR(chronic_med_condition, health_insurance)',
#  'OR(chronic_med_condition, health_worker)',
#  'OR(doctor_recc_h1n1, doctor_recc_seasonal)',
#  'OR(doctor_recc_h1n1, health_insurance)',
#  'OR(doctor_recc_h1n1, health_worker)',
#  'OR(doctor_recc_seasonal, health_insurance)',
#  'OR(doctor_recc_seasonal, health_worker)',
#  'OR(health_insurance, health_worker)',
#  'PERCENTILE(h1n1_concern)',
#  'PERCENTILE(h1n1_knowledge)',
#  'PERCENTILE(household_adults)',
#  'PERCENTILE(household_children)',
#  'PERCENTILE(opinion_h1n1_risk)',
#  'PERCENTILE(opinion_h1n1_sick_from_vacc)',
#  'PERCENTILE(opinion_h1n1_vacc_effective)',
#  'PERCENTILE(opinion_seas_risk)',
#  'PERCENTILE(opinion_seas_sick_from_vacc)',
#  'PERCENTILE(opinion_seas_vacc_effective)']

# %%
df_metrics = pd.DataFrame(df_metrics)

# %%
# best pipelines
df_metrics.sort_values(['roc_auc: h1n1_vaccine', 'roc_auc: seasonal_vaccine', 'shape'], ascending=[False, False, True]).reset_index().drop('index', axis=1)
# Out:
#                                      method  roc_auc: h1n1_vaccine  \
# 0                           pipeline_mutual                  0.957
# 1                          pipeline_emb_svc                  0.957
# 2                             pipeline_gbdt                  0.957
# 3                         pipeline_constant                  0.957
# 4                   pipeline_quasi_constant                  0.957
# 5                          rf_pipeline_base                  0.957
# 6                             pipeline_perm                  0.956
# 7                          pipeline_emb_log                  0.956
# 8                        lgbm_pipeline_base                  0.954
# 9                              pipeline_fgs                  0.954
# 10                       pipeline_emb_trees                  0.953
# 11  lgbm_pipeline_base_without_featuretools                  0.828
# 12                         pipeline_wrapper                  0.803
# 13                           pipeline_rfecv                  0.800
#
#     roc_auc: seasonal_vaccine  shape       time
# 0                       0.872    445    546.257
# 1                       0.872    456    722.578
# 2                       0.872    500    480.837
# 3                       0.872    524    571.131
# 4                       0.872    524    610.448
# 5                       0.852    524    792.537
# 6                       0.872    365   4325.102
# 7                       0.872    401    821.271
# 8                       0.872    524     80.383
# 9                       0.871    400    428.308
# 10                      0.869    182    513.456
# 11                      0.856     35      6.482
# 12                      0.834    165  43582.943
# 13                      0.834    353   4922.478

# %% [markdown]
# ## AutoML

# %% [markdown]
# ### TPOT

# %%
# Time measurement
start_time = time.time()

X_train_h1n1, X_test_h1n1, y_train_h1n1, y_test_h1n1 = train_test_split(
    X_selected_mutual_h1n1,
    y_h1n1,
    test_size=0.3,
    random_state=20,
    stratify=y_h1n1
)

X_train_seasonal, X_test_seasonal, y_train_seasonal, y_test_seasonal = train_test_split(
    X_selected_mutual_seasonal,
    y_seasonal,
    test_size=0.3,
    random_state=20,
    stratify=y_seasonal
)

tpot_pipeline_optimizer_h1n1 = TPOTClassifier(
    generations=5,
    population_size=20,
    cv=5,
    random_state=42,
    verbosity=2,
    max_eval_time_mins=1,
    n_jobs=-1,
)

tpot_pipeline_optimizer_seasonal = TPOTClassifier(
    generations=5,
    population_size=20,
    cv=5,
    random_state=42,
    verbosity=2,
    max_eval_time_mins=1,
    n_jobs=-1,
)

# Cross-validated roc auc
tpot_pipeline_optimizer_h1n1.fit(X_train_h1n1, y_train_h1n1)
tpot_pipeline_optimizer_seasonal.fit(X_train_seasonal, y_train_seasonal)

end_time = time.time() - start_time

print('ROC_AUC for h1n1: %0.3f' % (roc_auc_score(y_test_h1n1, tpot_pipeline_optimizer_h1n1.predict(X_test_h1n1))))
print('ROC_AUC for seasonal: %0.3f' % (roc_auc_score(y_test_seasonal, tpot_pipeline_optimizer_seasonal.predict(X_test_seasonal))))
# Out:
# Optimization Progress:   0%|          | 0/120 [00:00<?, ?pipeline/s]
# Generation 1 - Current best internal CV score: 0.838517993173656
#
# Generation 2 - Current best internal CV score: 0.838517993173656
#
# Generation 3 - Current best internal CV score: 0.838517993173656
#
# Generation 4 - Current best internal CV score: 0.8407253257130141
#
# Generation 5 - Current best internal CV score: 0.8407253257130141
#
# Best pipeline: DecisionTreeClassifier(StandardScaler(input_matrix), criterion=gini, max_depth=9, min_samples_leaf=9, min_samples_split=18)
# Optimization Progress:   0%|          | 0/120 [00:00<?, ?pipeline/s]
# Generation 1 - Current best internal CV score: 0.775975975975976
#
# Generation 2 - Current best internal CV score: 0.775975975975976
#
# Generation 3 - Current best internal CV score: 0.775975975975976
#
# Generation 4 - Current best internal CV score: 0.775975975975976
#
# Generation 5 - Current best internal CV score: 0.775975975975976
#
# Best pipeline: LinearSVC(SelectFwe(input_matrix, alpha=0.036000000000000004), C=0.0001, dual=True, loss=squared_hinge, penalty=l2, tol=0.001)
# ROC_AUC for h1n1: 0.843
# ROC_AUC for seasonal: 0.769

# %% [markdown]
# ### GAMA

# %%
# Time measurement
start_time = time.time()

gaml_pipeline_optimizer_h1n1 =  GamaClassifier(scoring='roc_auc', max_total_time=360, store="nothing", n_jobs=-1)
gaml_pipeline_optimizer_seasonal =  GamaClassifier(scoring='roc_auc', max_total_time=360, store="nothing", n_jobs=-1)

# Cross-validated roc auc
gaml_pipeline_optimizer_h1n1.fit(X_train_h1n1, y_train_h1n1)
gaml_pipeline_optimizer_seasonal.fit(X_train_seasonal, y_train_seasonal)

end_time = time.time() - start_time

print('ROC_AUC for h1n1: %0.3f' % (roc_auc_score(y_test_h1n1, gaml_pipeline_optimizer_h1n1.predict(X_test_h1n1))))
print('ROC_AUC for seasonal: %0.3f' % (roc_auc_score(y_test_seasonal, gaml_pipeline_optimizer_seasonal.predict(X_test_seasonal))))
# Out:
# ROC_AUC for h1n1: 0.776
# ROC_AUC for seasonal: 0.758

# %% [markdown]
# ### AutoSklearn (not working)

# %%
'''
# Time measurement
start_time = time.time()

autoskl_pipeline_optimizer = AutoSklearnClassifier()

# Cross-validated roc auc
scores_h1n1 = function_cross_val_score(autoskl_pipeline_optimizer, X_prep_h1n1, y.iloc[:,0], skf)
scores_seasonal = function_cross_val_score(autoskl_pipeline_optimizer, X_prep_seasonal, y.iloc[:,1], skf)

end_time = time.time() - start_time

print('Cross-validated ROC_AUC for h1n1: %0.3f +/- %0.3f' % (scores_h1n1.mean(), scores_h1n1.std()))
print('Cross-validated ROC_AUC for seasonal: %0.3f +/- %0.3f' % (scores_seasonal.mean(), scores_seasonal.std()))
'''

# %% [markdown]
# ## Prediction

# %% [markdown]
# ### permutation_importance pipeline: ROC_AUC in the competition - 0.7972

# %%
# Save results from best pipeline
X_test_selected_perm_h1n1 = selector_perm_h1n1.transform(X_test_prep_h1n1)
X_test_selected_perm_seasonal = selector_perm_seasonal.transform(X_test_prep_seasonal)

df_pred = pd.DataFrame()

df_pred['respondent_id'] = test_feat['respondent_id']

pipeline_perm.fit(X_selected_perm_h1n1, y_h1n1)
df_pred['h1n1_vaccine'] = lgbm_pipeline_perm.predict_proba(X_test_selected_perm_h1n1)[:, 1]

pipeline_perm.fit(X_selected_perm_seasonal, y_seasonal)
df_pred['seasonal_vaccine'] = lgbm_pipeline_perm.predict_proba(X_test_selected_perm_seasonal)[:, 1]

df_pred.to_csv('predictions_v1.csv', sep=',', index=False)

# Test ROC_AUC in the competition - 0.7972

# %% [markdown]
# ### mutual_info pipeline: ROC_AUC in the competition - 0.8263

# %%
# Save results from best pipeline
X_test_selected_mutual_h1n1 = selector_mutual_h1n1.transform(X_test_prep_h1n1)
X_test_selected_mutual_seasonal = selector_mutual_seasonal.transform(X_test_prep_seasonal)

df_pred = pd.DataFrame()

df_pred['respondent_id'] = test_feat['respondent_id']

rf_pipeline_mutual.fit(X_selected_mutual_h1n1, y_h1n1)
df_pred['h1n1_vaccine'] = rf_pipeline_mutual.predict_proba(X_test_selected_mutual_h1n1)[:, 1]

lgbm_pipeline_mutual.fit(X_selected_mutual_seasonal, y_seasonal)
df_pred['seasonal_vaccine'] = lgbm_pipeline_mutual.predict_proba(X_test_selected_mutual_seasonal)[:, 1]

df_pred.to_csv('predictions_v2.csv', sep=',', index=False)
